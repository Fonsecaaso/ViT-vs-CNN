# %% [markdown]
# https://keras.io/examples/vision/swin_transformers/

# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.20.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# !pip install tensorflow_hub

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
import functools

(train_ds, valid_ds), info = tfds.load("oxford_flowers102", split=["test", "validation"], as_supervised=True, with_info=True)
int_to_class_label = info.features['label'].int2str
num_classes = 102
IMG_WIDTH = IMG_HEIGHT = 120
input_shape = (IMG_WIDTH, IMG_HEIGHT, 3)

CLASSES_TO_CONSIDER = list(range(num_classes)) # only take first 20 classes for demo


def preprocess_image(image, label, height, width):
    image = tf.image.resize(image, [height,width])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def filter_by_classes(img, label):
    bools = tf.equal(label, CLASSES_TO_CONSIDER)
    return tf.reduce_any(bools)    


partial_preprocess_image = functools.partial(preprocess_image, height=IMG_HEIGHT, width=IMG_WIDTH)
train_ds = train_ds.filter(filter_by_classes).map(partial_preprocess_image).cache().shuffle(buffer_size=1000)
valid_ds = valid_ds.filter(filter_by_classes).map(partial_preprocess_image).cache().shuffle(buffer_size=1000)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (1.22.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (3.20.3)

# %%
def get_x_y_from_ds(ds):
    x, y = [], []
    for img, label in ds.cache().as_numpy_iterator():
        x.append(img)
        y.append(label)

    return np.array(x), np.array(y)

x_train, y_train = get_x_y_from_ds(train_ds)
x_test, y_test = get_x_y_from_ds(valid_ds)
# print(len(x_train), len(y_train), len(x_test), len(y_test)) # 200 200 200 200

# %%
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)

# %%
# num_classes = 100
# input_shape = (32, 32, 3)

# (x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()
# x_train, x_test = x_train / 255.0, x_test / 255.0
# y_train = keras.utils.to_categorical(y_train, num_classes)
# y_test = keras.utils.to_categorical(y_test, num_classes)
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
plt.show()
# Out:
# x_train shape: (6149, 120, 120, 3) - y_train shape: (6149, 102)
# x_test shape: (1020, 120, 120, 3) - y_test shape: (1020, 102)

# %%
patch_size = (2, 2)  # 2-by-2 sized patches
dropout_rate = 0.03  # Dropout rate
num_heads = 8  # Attention heads
embed_dim = 64  # Embedding dimension
num_mlp = 256  # MLP layer size
qkv_bias = True  # Convert embedded patches to query, key, and values with a learnable additive value
window_size = 2  # Size of attention window
shift_size = 1  # Size of shifting window
image_dimension = IMG_WIDTH  # Initial image size

num_patch_x = input_shape[0] // patch_size[0]
num_patch_y = input_shape[1] // patch_size[1]

learning_rate = 1e-3
batch_size = 128
num_epochs = 100
validation_split = 0.1
weight_decay = 0.0001
label_smoothing = 0.1

# %%
def window_partition(x, window_size):
    _, height, width, channels = x.shape
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        x, shape=(-1, patch_num_y, window_size, patch_num_x, window_size, channels)
    )
    x = tf.transpose(x, (0, 1, 3, 2, 4, 5))
    windows = tf.reshape(x, shape=(-1, window_size, window_size, channels))
    return windows


def window_reverse(windows, window_size, height, width, channels):
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        windows,
        shape=(-1, patch_num_y, patch_num_x, window_size, window_size, channels),
    )
    x = tf.transpose(x, perm=(0, 1, 3, 2, 4, 5))
    x = tf.reshape(x, shape=(-1, height, width, channels))
    return x


class DropPath(layers.Layer):
    def __init__(self, drop_prob=None, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prob

    def call(self, x):
        input_shape = tf.shape(x)
        batch_size = input_shape[0]
        rank = x.shape.rank
        shape = (batch_size,) + (1,) * (rank - 1)
        random_tensor = (1 - self.drop_prob) + tf.random.uniform(shape, dtype=x.dtype)
        path_mask = tf.floor(random_tensor)
        output = tf.math.divide(x, 1 - self.drop_prob) * path_mask
        return output

# %%
class WindowAttention(layers.Layer):
    def __init__(
        self, dim, window_size, num_heads, qkv_bias=True, dropout_rate=0.0, **kwargs
    ):
        super().__init__(**kwargs)
        self.dim = dim
        self.window_size = window_size
        self.num_heads = num_heads
        self.scale = (dim // num_heads) ** -0.5
        self.qkv = layers.Dense(dim * 3, use_bias=qkv_bias)
        self.dropout = layers.Dropout(dropout_rate)
        self.proj = layers.Dense(dim)

    def build(self, input_shape):
        num_window_elements = (2 * self.window_size[0] - 1) * (
            2 * self.window_size[1] - 1
        )
        self.relative_position_bias_table = self.add_weight(
            shape=(num_window_elements, self.num_heads),
            initializer=tf.initializers.Zeros(),
            trainable=True,
        )
        coords_h = np.arange(self.window_size[0])
        coords_w = np.arange(self.window_size[1])
        coords_matrix = np.meshgrid(coords_h, coords_w, indexing="ij")
        coords = np.stack(coords_matrix)
        coords_flatten = coords.reshape(2, -1)
        relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
        relative_coords = relative_coords.transpose([1, 2, 0])
        relative_coords[:, :, 0] += self.window_size[0] - 1
        relative_coords[:, :, 1] += self.window_size[1] - 1
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1
        relative_position_index = relative_coords.sum(-1)

        self.relative_position_index = tf.Variable(
            initial_value=tf.convert_to_tensor(relative_position_index), trainable=False
        )

    def call(self, x, mask=None):
        _, size, channels = x.shape
        head_dim = channels // self.num_heads
        x_qkv = self.qkv(x)
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, 3, self.num_heads, head_dim))
        x_qkv = tf.transpose(x_qkv, perm=(2, 0, 3, 1, 4))
        q, k, v = x_qkv[0], x_qkv[1], x_qkv[2]
        q = q * self.scale
        k = tf.transpose(k, perm=(0, 1, 3, 2))
        attn = q @ k

        num_window_elements = self.window_size[0] * self.window_size[1]
        relative_position_index_flat = tf.reshape(
            self.relative_position_index, shape=(-1,)
        )
        relative_position_bias = tf.gather(
            self.relative_position_bias_table, relative_position_index_flat
        )
        relative_position_bias = tf.reshape(
            relative_position_bias, shape=(num_window_elements, num_window_elements, -1)
        )
        relative_position_bias = tf.transpose(relative_position_bias, perm=(2, 0, 1))
        attn = attn + tf.expand_dims(relative_position_bias, axis=0)

        if mask is not None:
            nW = mask.get_shape()[0]
            mask_float = tf.cast(
                tf.expand_dims(tf.expand_dims(mask, axis=1), axis=0), tf.float32
            )
            attn = (
                tf.reshape(attn, shape=(-1, nW, self.num_heads, size, size))
                + mask_float
            )
            attn = tf.reshape(attn, shape=(-1, self.num_heads, size, size))
            attn = keras.activations.softmax(attn, axis=-1)
        else:
            attn = keras.activations.softmax(attn, axis=-1)
        attn = self.dropout(attn)

        x_qkv = attn @ v
        x_qkv = tf.transpose(x_qkv, perm=(0, 2, 1, 3))
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, channels))
        x_qkv = self.proj(x_qkv)
        x_qkv = self.dropout(x_qkv)
        return x_qkv

# %%
class SwinTransformer(layers.Layer):
    def __init__(
        self,
        dim,
        num_patch,
        num_heads,
        window_size=7,
        shift_size=0,
        num_mlp=1024,
        qkv_bias=True,
        dropout_rate=0.0,
        **kwargs,
    ):
        super().__init__(**kwargs)

        self.dim = dim  # number of input dimensions
        self.num_patch = num_patch  # number of embedded patches
        self.num_heads = num_heads  # number of attention heads
        self.window_size = window_size  # size of window
        self.shift_size = shift_size  # size of window shift
        self.num_mlp = num_mlp  # number of MLP nodes

        self.norm1 = layers.LayerNormalization(epsilon=1e-5)
        self.attn = WindowAttention(
            dim,
            window_size=(self.window_size, self.window_size),
            num_heads=num_heads,
            qkv_bias=qkv_bias,
            dropout_rate=dropout_rate,
        )
        self.drop_path = DropPath(dropout_rate)
        self.norm2 = layers.LayerNormalization(epsilon=1e-5)

        self.mlp = keras.Sequential(
            [
                layers.Dense(num_mlp),
                layers.Activation(keras.activations.gelu),
                layers.Dropout(dropout_rate),
                layers.Dense(dim),
                layers.Dropout(dropout_rate),
            ]
        )

        if min(self.num_patch) < self.window_size:
            self.shift_size = 0
            self.window_size = min(self.num_patch)

    def build(self, input_shape):
        if self.shift_size == 0:
            self.attn_mask = None
        else:
            height, width = self.num_patch
            h_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            w_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            mask_array = np.zeros((1, height, width, 1))
            count = 0
            for h in h_slices:
                for w in w_slices:
                    mask_array[:, h, w, :] = count
                    count += 1
            mask_array = tf.convert_to_tensor(mask_array)

            # mask array to windows
            mask_windows = window_partition(mask_array, self.window_size)
            mask_windows = tf.reshape(
                mask_windows, shape=[-1, self.window_size * self.window_size]
            )
            attn_mask = tf.expand_dims(mask_windows, axis=1) - tf.expand_dims(
                mask_windows, axis=2
            )
            attn_mask = tf.where(attn_mask != 0, -100.0, attn_mask)
            attn_mask = tf.where(attn_mask == 0, 0.0, attn_mask)
            self.attn_mask = tf.Variable(initial_value=attn_mask, trainable=False)

    def call(self, x):
        height, width = self.num_patch
        _, num_patches_before, channels = x.shape
        x_skip = x
        x = self.norm1(x)
        x = tf.reshape(x, shape=(-1, height, width, channels))
        if self.shift_size > 0:
            shifted_x = tf.roll(
                x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2]
            )
        else:
            shifted_x = x

        x_windows = window_partition(shifted_x, self.window_size)
        x_windows = tf.reshape(
            x_windows, shape=(-1, self.window_size * self.window_size, channels)
        )
        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        attn_windows = tf.reshape(
            attn_windows, shape=(-1, self.window_size, self.window_size, channels)
        )
        shifted_x = window_reverse(
            attn_windows, self.window_size, height, width, channels
        )
        if self.shift_size > 0:
            x = tf.roll(
                shifted_x, shift=[self.shift_size, self.shift_size], axis=[1, 2]
            )
        else:
            x = shifted_x

        x = tf.reshape(x, shape=(-1, height * width, channels))
        x = self.drop_path(x)
        x = x_skip + x
        x_skip = x
        x = self.norm2(x)
        x = self.mlp(x)
        x = self.drop_path(x)
        x = x_skip + x
        return x

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size_x = patch_size[0]
        self.patch_size_y = patch_size[0]

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size_x, self.patch_size_y, 1),
            strides=(1, self.patch_size_x, self.patch_size_y, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)


class PatchMerging(tf.keras.layers.Layer):
    def __init__(self, num_patch, embed_dim):
        super().__init__()
        self.num_patch = num_patch
        self.embed_dim = embed_dim
        self.linear_trans = layers.Dense(2 * embed_dim, use_bias=False)

    def call(self, x):
        height, width = self.num_patch
        _, _, C = x.get_shape().as_list()
        x = tf.reshape(x, shape=(-1, height, width, C))
        x0 = x[:, 0::2, 0::2, :]
        x1 = x[:, 1::2, 0::2, :]
        x2 = x[:, 0::2, 1::2, :]
        x3 = x[:, 1::2, 1::2, :]
        x = tf.concat((x0, x1, x2, x3), axis=-1)
        x = tf.reshape(x, shape=(-1, (height // 2) * (width // 2), 4 * C))
        return self.linear_trans(x)

# %%
input = layers.Input(input_shape)
x = layers.RandomCrop(image_dimension, image_dimension)(input)
x = layers.RandomFlip("horizontal")(x)
x = PatchExtract(patch_size)(x)
x = PatchEmbedding(num_patch_x * num_patch_y, embed_dim)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=0,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=shift_size,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = PatchMerging((num_patch_x, num_patch_y), embed_dim=embed_dim)(x)
x = layers.GlobalAveragePooling1D()(x)
output = layers.Dense(num_classes, activation="softmax")(x)

# %%
model = keras.Model(input, output)
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=validation_split,
)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 20s 324ms/step - loss: 4.4161 - accuracy: 0.0685 - top-5-accuracy: 0.2065 - val_loss: 4.0722 - val_accuracy: 0.0959 - val_top-5-accuracy: 0.3106
# Epoch 2/100
# 44/44 [==============================] - 12s 277ms/step - loss: 3.9121 - accuracy: 0.1362 - top-5-accuracy: 0.3598 - val_loss: 3.7848 - val_accuracy: 0.1545 - val_top-5-accuracy: 0.4049
# Epoch 3/100
# 44/44 [==============================] - 12s 277ms/step - loss: 3.6240 - accuracy: 0.1982 - top-5-accuracy: 0.4668 - val_loss: 3.5900 - val_accuracy: 0.2081 - val_top-5-accuracy: 0.4780
# Epoch 4/100
# 44/44 [==============================] - 12s 277ms/step - loss: 3.4387 - accuracy: 0.2420 - top-5-accuracy: 0.5197 - val_loss: 3.4033 - val_accuracy: 0.2472 - val_top-5-accuracy: 0.5561
# Epoch 5/100
# 44/44 [==============================] - 12s 276ms/step - loss: 3.2819 - accuracy: 0.2835 - top-5-accuracy: 0.5701 - val_loss: 3.2877 - val_accuracy: 0.2846 - val_top-5-accuracy: 0.5967
# Epoch 6/100
# 44/44 [==============================] - 12s 277ms/step - loss: 3.1876 - accuracy: 0.3036 - top-5-accuracy: 0.6048 - val_loss: 3.1822 - val_accuracy: 0.3268 - val_top-5-accuracy: 0.6358
# Epoch 7/100
# 44/44 [==============================] - 12s 276ms/step - loss: 3.0647 - accuracy: 0.3352 - top-5-accuracy: 0.6458 - val_loss: 3.1474 - val_accuracy: 0.3285 - val_top-5-accuracy: 0.6423
# Epoch 8/100
# 44/44 [==============================] - 12s 277ms/step - loss: 3.0022 - accuracy: 0.3540 - top-5-accuracy: 0.6583 - val_loss: 3.1066 - val_accuracy: 0.3366 - val_top-5-accuracy: 0.6407
# Epoch 9/100
# 44/44 [==============================] - 12s 279ms/step - loss: 2.8967 - accuracy: 0.3853 - top-5-accuracy: 0.6915 - val_loss: 2.9202 - val_accuracy: 0.3919 - val_top-5-accuracy: 0.6976
# Epoch 10/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.8420 - accuracy: 0.4068 - top-5-accuracy: 0.7060 - val_loss: 2.8498 - val_accuracy: 0.3935 - val_top-5-accuracy: 0.7073
# Epoch 11/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.7810 - accuracy: 0.4201 - top-5-accuracy: 0.7224 - val_loss: 2.9183 - val_accuracy: 0.3919 - val_top-5-accuracy: 0.6927
# Epoch 12/100
# 44/44 [==============================] - 12s 278ms/step - loss: 2.7379 - accuracy: 0.4357 - top-5-accuracy: 0.7320 - val_loss: 2.9345 - val_accuracy: 0.3935 - val_top-5-accuracy: 0.6959
# Epoch 13/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.7108 - accuracy: 0.4458 - top-5-accuracy: 0.7456 - val_loss: 2.7605 - val_accuracy: 0.4407 - val_top-5-accuracy: 0.7382
# Epoch 14/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.6504 - accuracy: 0.4626 - top-5-accuracy: 0.7591 - val_loss: 2.8143 - val_accuracy: 0.4390 - val_top-5-accuracy: 0.7236
# Epoch 15/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.6024 - accuracy: 0.4792 - top-5-accuracy: 0.7723 - val_loss: 2.6712 - val_accuracy: 0.4732 - val_top-5-accuracy: 0.7642
# Epoch 16/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.5396 - accuracy: 0.5076 - top-5-accuracy: 0.7891 - val_loss: 2.7201 - val_accuracy: 0.4407 - val_top-5-accuracy: 0.7480
# Epoch 17/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.5142 - accuracy: 0.5078 - top-5-accuracy: 0.7875 - val_loss: 2.6612 - val_accuracy: 0.4764 - val_top-5-accuracy: 0.7447
# Epoch 18/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.4822 - accuracy: 0.5141 - top-5-accuracy: 0.7973 - val_loss: 2.6548 - val_accuracy: 0.4732 - val_top-5-accuracy: 0.7610
# Epoch 19/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.4634 - accuracy: 0.5237 - top-5-accuracy: 0.8025 - val_loss: 2.6013 - val_accuracy: 0.5073 - val_top-5-accuracy: 0.7593
# Epoch 20/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.3987 - accuracy: 0.5408 - top-5-accuracy: 0.8188 - val_loss: 2.6494 - val_accuracy: 0.4618 - val_top-5-accuracy: 0.7398
# Epoch 21/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.3587 - accuracy: 0.5575 - top-5-accuracy: 0.8272 - val_loss: 2.5081 - val_accuracy: 0.5154 - val_top-5-accuracy: 0.7935
# Epoch 22/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.3295 - accuracy: 0.5696 - top-5-accuracy: 0.8383 - val_loss: 2.5243 - val_accuracy: 0.5089 - val_top-5-accuracy: 0.7902
# Epoch 23/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.3289 - accuracy: 0.5687 - top-5-accuracy: 0.8366 - val_loss: 2.5688 - val_accuracy: 0.5106 - val_top-5-accuracy: 0.7610
# Epoch 24/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.2762 - accuracy: 0.5793 - top-5-accuracy: 0.8475 - val_loss: 2.5990 - val_accuracy: 0.4878 - val_top-5-accuracy: 0.7691
# Epoch 25/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.2509 - accuracy: 0.5876 - top-5-accuracy: 0.8547 - val_loss: 2.5248 - val_accuracy: 0.5171 - val_top-5-accuracy: 0.7707
# Epoch 26/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.2173 - accuracy: 0.5994 - top-5-accuracy: 0.8647 - val_loss: 2.5818 - val_accuracy: 0.4911 - val_top-5-accuracy: 0.7756
# Epoch 27/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.1973 - accuracy: 0.6131 - top-5-accuracy: 0.8618 - val_loss: 2.5239 - val_accuracy: 0.5154 - val_top-5-accuracy: 0.7886
# Epoch 28/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.1591 - accuracy: 0.6147 - top-5-accuracy: 0.8712 - val_loss: 2.4930 - val_accuracy: 0.5122 - val_top-5-accuracy: 0.7967
# Epoch 29/100
# 44/44 [==============================] - 12s 277ms/step - loss: 2.1152 - accuracy: 0.6442 - top-5-accuracy: 0.8820 - val_loss: 2.5090 - val_accuracy: 0.5220 - val_top-5-accuracy: 0.7984
# Epoch 30/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.1027 - accuracy: 0.6462 - top-5-accuracy: 0.8860 - val_loss: 2.4924 - val_accuracy: 0.5171 - val_top-5-accuracy: 0.7984
# Epoch 31/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.0630 - accuracy: 0.6606 - top-5-accuracy: 0.8890 - val_loss: 2.4192 - val_accuracy: 0.5724 - val_top-5-accuracy: 0.8163
# Epoch 32/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.0648 - accuracy: 0.6572 - top-5-accuracy: 0.8934 - val_loss: 2.3464 - val_accuracy: 0.5789 - val_top-5-accuracy: 0.8325
# Epoch 33/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.0579 - accuracy: 0.6578 - top-5-accuracy: 0.8941 - val_loss: 2.4289 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.8114
# Epoch 34/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.0278 - accuracy: 0.6760 - top-5-accuracy: 0.9001 - val_loss: 2.4243 - val_accuracy: 0.5463 - val_top-5-accuracy: 0.8130
# Epoch 35/100
# 44/44 [==============================] - 12s 276ms/step - loss: 2.0146 - accuracy: 0.6755 - top-5-accuracy: 0.9012 - val_loss: 2.4222 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.8146
# Epoch 36/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.9639 - accuracy: 0.6943 - top-5-accuracy: 0.9107 - val_loss: 2.3731 - val_accuracy: 0.5626 - val_top-5-accuracy: 0.8211
# Epoch 37/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.9554 - accuracy: 0.7000 - top-5-accuracy: 0.9104 - val_loss: 2.3415 - val_accuracy: 0.5805 - val_top-5-accuracy: 0.8260
# Epoch 38/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.9506 - accuracy: 0.7024 - top-5-accuracy: 0.9183 - val_loss: 2.4525 - val_accuracy: 0.5333 - val_top-5-accuracy: 0.8130
# Epoch 39/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.9411 - accuracy: 0.6993 - top-5-accuracy: 0.9214 - val_loss: 2.4739 - val_accuracy: 0.5366 - val_top-5-accuracy: 0.8211
# Epoch 40/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.8935 - accuracy: 0.7210 - top-5-accuracy: 0.9246 - val_loss: 2.3640 - val_accuracy: 0.5805 - val_top-5-accuracy: 0.8195
# Epoch 41/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.8678 - accuracy: 0.7295 - top-5-accuracy: 0.9306 - val_loss: 2.3865 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.8309
# Epoch 42/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.8527 - accuracy: 0.7378 - top-5-accuracy: 0.9272 - val_loss: 2.3674 - val_accuracy: 0.5886 - val_top-5-accuracy: 0.8276
# Epoch 43/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.8198 - accuracy: 0.7470 - top-5-accuracy: 0.9366 - val_loss: 2.3952 - val_accuracy: 0.5512 - val_top-5-accuracy: 0.8309
# Epoch 44/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.8013 - accuracy: 0.7553 - top-5-accuracy: 0.9378 - val_loss: 2.3964 - val_accuracy: 0.5593 - val_top-5-accuracy: 0.8374
# Epoch 45/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.8074 - accuracy: 0.7523 - top-5-accuracy: 0.9371 - val_loss: 2.3823 - val_accuracy: 0.5919 - val_top-5-accuracy: 0.8244
# Epoch 46/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.7959 - accuracy: 0.7611 - top-5-accuracy: 0.9404 - val_loss: 2.3927 - val_accuracy: 0.5837 - val_top-5-accuracy: 0.8244
# Epoch 47/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.7525 - accuracy: 0.7815 - top-5-accuracy: 0.9445 - val_loss: 2.5605 - val_accuracy: 0.5236 - val_top-5-accuracy: 0.8065
# Epoch 48/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.7417 - accuracy: 0.7842 - top-5-accuracy: 0.9467 - val_loss: 2.3527 - val_accuracy: 0.5740 - val_top-5-accuracy: 0.8276
# Epoch 49/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.7445 - accuracy: 0.7781 - top-5-accuracy: 0.9462 - val_loss: 2.3928 - val_accuracy: 0.5805 - val_top-5-accuracy: 0.8276
# Epoch 50/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.7566 - accuracy: 0.7772 - top-5-accuracy: 0.9451 - val_loss: 2.3995 - val_accuracy: 0.5805 - val_top-5-accuracy: 0.8211
# Epoch 51/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.6898 - accuracy: 0.8090 - top-5-accuracy: 0.9518 - val_loss: 2.6157 - val_accuracy: 0.5301 - val_top-5-accuracy: 0.8130
# Epoch 52/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.6761 - accuracy: 0.8027 - top-5-accuracy: 0.9586 - val_loss: 2.3253 - val_accuracy: 0.5675 - val_top-5-accuracy: 0.8504
# Epoch 53/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.7007 - accuracy: 0.7991 - top-5-accuracy: 0.9523 - val_loss: 2.4284 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.8179
# Epoch 54/100
# 44/44 [==============================] - 12s 278ms/step - loss: 1.6747 - accuracy: 0.8090 - top-5-accuracy: 0.9555 - val_loss: 2.4282 - val_accuracy: 0.5772 - val_top-5-accuracy: 0.8390
# Epoch 55/100
# 44/44 [==============================] - 12s 278ms/step - loss: 1.6718 - accuracy: 0.8148 - top-5-accuracy: 0.9575 - val_loss: 2.4480 - val_accuracy: 0.5382 - val_top-5-accuracy: 0.8325
# Epoch 56/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.6877 - accuracy: 0.8034 - top-5-accuracy: 0.9534 - val_loss: 2.5115 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.8309
# Epoch 57/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.6614 - accuracy: 0.8148 - top-5-accuracy: 0.9597 - val_loss: 2.3686 - val_accuracy: 0.5789 - val_top-5-accuracy: 0.8309
# Epoch 58/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.6273 - accuracy: 0.8258 - top-5-accuracy: 0.9601 - val_loss: 2.4026 - val_accuracy: 0.5610 - val_top-5-accuracy: 0.8179
# Epoch 59/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.5802 - accuracy: 0.8504 - top-5-accuracy: 0.9658 - val_loss: 2.3940 - val_accuracy: 0.5593 - val_top-5-accuracy: 0.8244
# Epoch 60/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.5899 - accuracy: 0.8522 - top-5-accuracy: 0.9622 - val_loss: 2.3727 - val_accuracy: 0.5789 - val_top-5-accuracy: 0.8276
# Epoch 61/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.5920 - accuracy: 0.8388 - top-5-accuracy: 0.9658 - val_loss: 2.7162 - val_accuracy: 0.5203 - val_top-5-accuracy: 0.7561
# Epoch 62/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.5912 - accuracy: 0.8399 - top-5-accuracy: 0.9671 - val_loss: 2.3554 - val_accuracy: 0.5805 - val_top-5-accuracy: 0.8407
# Epoch 63/100
# 44/44 [==============================] - 12s 280ms/step - loss: 1.5766 - accuracy: 0.8489 - top-5-accuracy: 0.9642 - val_loss: 2.3652 - val_accuracy: 0.5967 - val_top-5-accuracy: 0.8439
# Epoch 64/100
# 44/44 [==============================] - 12s 280ms/step - loss: 1.5524 - accuracy: 0.8585 - top-5-accuracy: 0.9702 - val_loss: 2.5182 - val_accuracy: 0.5382 - val_top-5-accuracy: 0.8065
# Epoch 65/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.5242 - accuracy: 0.8739 - top-5-accuracy: 0.9727 - val_loss: 2.5093 - val_accuracy: 0.5659 - val_top-5-accuracy: 0.8179
# Epoch 66/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.5030 - accuracy: 0.8824 - top-5-accuracy: 0.9720 - val_loss: 2.4084 - val_accuracy: 0.5480 - val_top-5-accuracy: 0.8276
# Epoch 67/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.5074 - accuracy: 0.8735 - top-5-accuracy: 0.9751 - val_loss: 2.4524 - val_accuracy: 0.5675 - val_top-5-accuracy: 0.8309
# Epoch 68/100
# 44/44 [==============================] - 12s 278ms/step - loss: 1.5357 - accuracy: 0.8654 - top-5-accuracy: 0.9695 - val_loss: 2.5737 - val_accuracy: 0.5350 - val_top-5-accuracy: 0.7919
# Epoch 69/100
# 44/44 [==============================] - 12s 278ms/step - loss: 1.5276 - accuracy: 0.8706 - top-5-accuracy: 0.9673 - val_loss: 2.4094 - val_accuracy: 0.5854 - val_top-5-accuracy: 0.8260
# Epoch 70/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.5016 - accuracy: 0.8759 - top-5-accuracy: 0.9722 - val_loss: 2.5629 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.7984
# Epoch 71/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.4942 - accuracy: 0.8820 - top-5-accuracy: 0.9774 - val_loss: 2.4277 - val_accuracy: 0.5447 - val_top-5-accuracy: 0.8260
# Epoch 72/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4927 - accuracy: 0.8853 - top-5-accuracy: 0.9709 - val_loss: 2.5656 - val_accuracy: 0.5187 - val_top-5-accuracy: 0.8260
# Epoch 73/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.4851 - accuracy: 0.8849 - top-5-accuracy: 0.9754 - val_loss: 2.5925 - val_accuracy: 0.5512 - val_top-5-accuracy: 0.7837
# Epoch 74/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.4797 - accuracy: 0.8894 - top-5-accuracy: 0.9752 - val_loss: 2.5981 - val_accuracy: 0.5252 - val_top-5-accuracy: 0.7967
# Epoch 75/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4861 - accuracy: 0.8847 - top-5-accuracy: 0.9761 - val_loss: 2.4562 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8114
# Epoch 76/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4633 - accuracy: 0.8945 - top-5-accuracy: 0.9756 - val_loss: 2.5239 - val_accuracy: 0.5626 - val_top-5-accuracy: 0.8033
# Epoch 77/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4532 - accuracy: 0.8952 - top-5-accuracy: 0.9778 - val_loss: 2.4849 - val_accuracy: 0.5528 - val_top-5-accuracy: 0.8146
# Epoch 78/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4567 - accuracy: 0.8952 - top-5-accuracy: 0.9771 - val_loss: 2.4555 - val_accuracy: 0.5675 - val_top-5-accuracy: 0.8211
# Epoch 79/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4482 - accuracy: 0.9001 - top-5-accuracy: 0.9751 - val_loss: 2.5187 - val_accuracy: 0.5561 - val_top-5-accuracy: 0.8276
# Epoch 80/100
# 44/44 [==============================] - 12s 277ms/step - loss: 1.4357 - accuracy: 0.9050 - top-5-accuracy: 0.9790 - val_loss: 2.4766 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8374
# Epoch 81/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4429 - accuracy: 0.9022 - top-5-accuracy: 0.9780 - val_loss: 2.4485 - val_accuracy: 0.5463 - val_top-5-accuracy: 0.8374
# Epoch 82/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4106 - accuracy: 0.9124 - top-5-accuracy: 0.9763 - val_loss: 2.4417 - val_accuracy: 0.5398 - val_top-5-accuracy: 0.8195
# Epoch 83/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4071 - accuracy: 0.9147 - top-5-accuracy: 0.9794 - val_loss: 2.4777 - val_accuracy: 0.5577 - val_top-5-accuracy: 0.8146
# Epoch 84/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4182 - accuracy: 0.9156 - top-5-accuracy: 0.9765 - val_loss: 2.4338 - val_accuracy: 0.5480 - val_top-5-accuracy: 0.8163
# Epoch 85/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4091 - accuracy: 0.9140 - top-5-accuracy: 0.9751 - val_loss: 2.4431 - val_accuracy: 0.5626 - val_top-5-accuracy: 0.8179
# Epoch 86/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3947 - accuracy: 0.9181 - top-5-accuracy: 0.9794 - val_loss: 2.5112 - val_accuracy: 0.5577 - val_top-5-accuracy: 0.8211
# Epoch 87/100
# 44/44 [==============================] - 12s 275ms/step - loss: 1.3876 - accuracy: 0.9153 - top-5-accuracy: 0.9810 - val_loss: 2.4658 - val_accuracy: 0.5398 - val_top-5-accuracy: 0.8114
# Epoch 88/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4018 - accuracy: 0.9142 - top-5-accuracy: 0.9794 - val_loss: 2.4745 - val_accuracy: 0.5659 - val_top-5-accuracy: 0.8179
# Epoch 89/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4063 - accuracy: 0.9082 - top-5-accuracy: 0.9790 - val_loss: 2.4692 - val_accuracy: 0.5350 - val_top-5-accuracy: 0.8341
# Epoch 90/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4050 - accuracy: 0.9138 - top-5-accuracy: 0.9781 - val_loss: 2.5102 - val_accuracy: 0.5561 - val_top-5-accuracy: 0.8114
# Epoch 91/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3707 - accuracy: 0.9266 - top-5-accuracy: 0.9827 - val_loss: 2.4734 - val_accuracy: 0.5512 - val_top-5-accuracy: 0.8114
# Epoch 92/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3877 - accuracy: 0.9180 - top-5-accuracy: 0.9776 - val_loss: 2.5169 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8049
# Epoch 93/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3735 - accuracy: 0.9236 - top-5-accuracy: 0.9799 - val_loss: 2.5794 - val_accuracy: 0.5398 - val_top-5-accuracy: 0.7935
# Epoch 94/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3721 - accuracy: 0.9187 - top-5-accuracy: 0.9778 - val_loss: 2.4713 - val_accuracy: 0.5512 - val_top-5-accuracy: 0.8114
# Epoch 95/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.4021 - accuracy: 0.9093 - top-5-accuracy: 0.9794 - val_loss: 2.4524 - val_accuracy: 0.5626 - val_top-5-accuracy: 0.8293
# Epoch 96/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3875 - accuracy: 0.9194 - top-5-accuracy: 0.9817 - val_loss: 2.4713 - val_accuracy: 0.5285 - val_top-5-accuracy: 0.8130
# Epoch 97/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3716 - accuracy: 0.9218 - top-5-accuracy: 0.9808 - val_loss: 2.4853 - val_accuracy: 0.5398 - val_top-5-accuracy: 0.8081
# Epoch 98/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3482 - accuracy: 0.9330 - top-5-accuracy: 0.9863 - val_loss: 2.5549 - val_accuracy: 0.5447 - val_top-5-accuracy: 0.8033
# Epoch 99/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3493 - accuracy: 0.9322 - top-5-accuracy: 0.9817 - val_loss: 2.4643 - val_accuracy: 0.5577 - val_top-5-accuracy: 0.8179
# Epoch 100/100
# 44/44 [==============================] - 12s 276ms/step - loss: 1.3296 - accuracy: 0.9317 - top-5-accuracy: 0.9836 - val_loss: 2.4401 - val_accuracy: 0.5447 - val_top-5-accuracy: 0.8130

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

plt.plot(history.history["accuracy"], label="test_accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation accuracies Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
y_pred = model.predict(x_test)
predicted_ids = np.argmax(y_pred, axis=-1)
true_classes = np.argmax(y_test, axis=-1)
accuracy = np.mean(predicted_ids == true_classes)
print('Precisão:', accuracy)
# Out:
# 32/32 [==============================] - 2s 27ms/step
# Precisão: 0.4715686274509804

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report

# Calcular a precisão, recall e F1-score para cada classe
report = classification_report(true_classes, predicted_ids, target_names=np.array(info.features['label'].names))

# Exibir o relatório de classificação
print(report)
# Out:
#                            precision    recall  f1-score   support
#
#             pink primrose       0.33      0.10      0.15        10
# hard-leaved pocket orchid       0.75      0.30      0.43        10
#          canterbury bells       0.00      0.00      0.00        10
#                 sweet pea       0.29      0.20      0.24        10
#          english marigold       0.40      0.40      0.40        10
#                tiger lily       0.75      0.30      0.43        10
#               moon orchid       0.60      0.30      0.40        10
#          bird of paradise       0.70      0.70      0.70        10
#                 monkshood       0.25      0.10      0.14        10
#             globe thistle       0.70      0.70      0.70        10
#                snapdragon       0.22      0.20      0.21        10
#               colt's foot       0.75      0.90      0.82        10
#               king protea       1.00      0.60      0.75        10
#             spear thistle       1.00      0.60      0.75        10
#               yellow iris       0.57      0.40      0.47        10
#              globe-flower       0.00      0.00      0.00        10
#         purple coneflower       0.75      0.60      0.67        10
#             peruvian lily       0.38      0.30      0.33        10
#            balloon flower       1.00      0.10      0.18        10
#     giant white arum lily       0.17      0.20      0.18        10
#                 fire lily       1.00      0.40      0.57        10
#         pincushion flower       0.86      0.60      0.71        10
#                fritillary       0.36      0.40      0.38        10
#                red ginger       0.73      0.80      0.76        10
#            grape hyacinth       0.50      0.50      0.50        10
#                corn poppy       0.60      0.30      0.40        10
#  prince of wales feathers       1.00      0.20      0.33        10
#          stemless gentian       0.75      0.60      0.67        10
#                 artichoke       0.67      0.40      0.50        10
#             sweet william       0.67      0.40      0.50        10
#                 carnation       0.60      0.30      0.40        10
#              garden phlox       1.00      0.10      0.18        10
#          love in the mist       0.62      0.50      0.56        10
#             mexican aster       0.50      0.20      0.29        10
#          alpine sea holly       0.57      0.40      0.47        10
#      ruby-lipped cattleya       0.50      0.20      0.29        10
#               cape flower       1.00      0.50      0.67        10
#          great masterwort       0.67      0.20      0.31        10
#                siam tulip       1.00      0.40      0.57        10
#               lenten rose       0.23      0.30      0.26        10
#            barbeton daisy       0.33      0.50      0.40        10
#                  daffodil       0.38      0.30      0.33        10
#                sword lily       0.04      0.10      0.06        10
#                poinsettia       0.43      0.30      0.35        10
#          bolero deep blue       0.80      0.40      0.53        10
#                wallflower       0.30      0.90      0.45        10
#                  marigold       0.43      0.60      0.50        10
#                 buttercup       0.29      0.50      0.37        10
#               oxeye daisy       0.83      0.50      0.62        10
#          common dandelion       0.71      0.50      0.59        10
#                   petunia       0.23      0.70      0.34        10
#                wild pansy       0.56      0.90      0.69        10
#                   primula       0.33      0.60      0.43        10
#                 sunflower       1.00      0.70      0.82        10
#               pelargonium       0.86      0.60      0.71        10
#        bishop of llandaff       0.67      1.00      0.80        10
#                     gaura       0.62      0.80      0.70        10
#                  geranium       0.82      0.90      0.86        10
#             orange dahlia       1.00      0.50      0.67        10
#       pink-yellow dahlia?       0.75      0.90      0.82        10
#          cautleya spicata       0.83      1.00      0.91        10
#          japanese anemone       0.50      0.40      0.44        10
#          black-eyed susan       1.00      0.90      0.95        10
#                silverbush       1.00      0.80      0.89        10
#         californian poppy       0.77      1.00      0.87        10
#              osteospermum       0.88      0.70      0.78        10
#             spring crocus       0.33      0.10      0.15        10
#              bearded iris       0.62      0.50      0.56        10
#                windflower       0.57      0.40      0.47        10
#                tree poppy       0.50      0.40      0.44        10
#                   gazania       0.83      1.00      0.91        10
#                    azalea       0.20      0.10      0.13        10
#                water lily       0.56      0.50      0.53        10
#                      rose       0.29      0.50      0.37        10
#               thorn apple       0.40      1.00      0.57        10
#             morning glory       0.26      0.60      0.36        10
#            passion flower       0.26      0.90      0.41        10
#                     lotus       0.39      0.70      0.50        10
#                 toad lily       0.50      0.20      0.29        10
#                 anthurium       0.25      0.10      0.14        10
#                frangipani       0.42      0.80      0.55        10
#                  clematis       0.20      0.30      0.24        10
#                  hibiscus       0.57      0.40      0.47        10
#                 columbine       0.22      0.50      0.30        10
#               desert-rose       0.40      0.60      0.48        10
#               tree mallow       0.62      0.50      0.56        10
#                  magnolia       0.35      0.60      0.44        10
#                  cyclamen       0.24      0.80      0.37        10
#                watercress       0.33      0.50      0.40        10
#                canna lily       0.50      0.10      0.17        10
#               hippeastrum       0.50      0.40      0.44        10
#                  bee balm       0.43      0.60      0.50        10
#                 ball moss       1.00      0.10      0.18        10
#                  foxglove       0.36      0.40      0.38        10
#             bougainvillea       0.18      0.40      0.25        10
#                  camellia       0.29      0.60      0.39        10
#                    mallow       0.44      0.40      0.42        10
#           mexican petunia       0.33      0.20      0.25        10
#                  bromelia       0.50      0.30      0.37        10
#            blanket flower       1.00      0.50      0.67        10
#           trumpet creeper       0.00      0.00      0.00        10
#           blackberry lily       0.67      0.40      0.50        10
#
#                  accuracy                           0.47      1020
#                 macro avg       0.55      0.47      0.46      1020
#              weighted avg       0.55      0.47      0.46      1020
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
