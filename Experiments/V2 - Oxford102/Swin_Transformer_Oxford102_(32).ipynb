# %%
# !pip install -U tensorflow-addons
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.20.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
# !pip install tensorflow_hub

import tensorflow as tf
import tensorflow_hub as hub
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt
import functools

(train_ds, valid_ds), info = tfds.load("oxford_flowers102", split=["test", "validation"], as_supervised=True, with_info=True)
int_to_class_label = info.features['label'].int2str
num_classes = 102
input_shape = (32, 32, 3)

CLASSES_TO_CONSIDER = list(range(102)) # only take first 20 classes for demo
IMG_WIDTH = IMG_HEIGHT = 32

def preprocess_image(image, label, height, width):
    image = tf.image.resize(image, [height,width])
    image = tf.cast(image, tf.float32) / 255.0
    return image, label

def filter_by_classes(img, label):
    bools = tf.equal(label, CLASSES_TO_CONSIDER)
    return tf.reduce_any(bools)    


partial_preprocess_image = functools.partial(preprocess_image, height=IMG_HEIGHT, width=IMG_WIDTH)
train_ds = train_ds.filter(filter_by_classes).map(partial_preprocess_image).cache().shuffle(buffer_size=1000)
valid_ds = valid_ds.filter(filter_by_classes).map(partial_preprocess_image).cache().shuffle(buffer_size=1000)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (1.22.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow_hub) (3.20.3)

# %%
def get_x_y_from_ds(ds):
    x, y = [], []
    for img, label in ds.cache().as_numpy_iterator():
        x.append(img)
        y.append(label)

    return np.array(x), np.array(y)

x_train, y_train = get_x_y_from_ds(train_ds)
x_test, y_test = get_x_y_from_ds(valid_ds)
# print(len(x_train), len(y_train), len(x_test), len(y_test)) # 200 200 200 200

# %%
y_test = tf.keras.utils.to_categorical(y_test, num_classes)
y_train = tf.keras.utils.to_categorical(y_train, num_classes)

# %%
# num_classes = 100
# input_shape = (32, 32, 3)

# (x_train, y_train), (x_test, y_test) = keras.datasets.cifar100.load_data()
# x_train, x_test = x_train / 255.0, x_test / 255.0
# y_train = keras.utils.to_categorical(y_train, num_classes)
# y_test = keras.utils.to_categorical(y_test, num_classes)
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")

plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
plt.show()
# Out:
# x_train shape: (6149, 32, 32, 3) - y_train shape: (6149, 102)
# x_test shape: (1020, 32, 32, 3) - y_test shape: (1020, 102)

# %%
patch_size = (2, 2)  # 2-by-2 sized patches
dropout_rate = 0.03  # Dropout rate
num_heads = 8  # Attention heads
embed_dim = 64  # Embedding dimension
num_mlp = 256  # MLP layer size
qkv_bias = True  # Convert embedded patches to query, key, and values with a learnable additive value
window_size = 2  # Size of attention window
shift_size = 1  # Size of shifting window
image_dimension = 32  # Initial image size

num_patch_x = input_shape[0] // patch_size[0]
num_patch_y = input_shape[1] // patch_size[1]

learning_rate = 1e-3
batch_size = 128
num_epochs = 100
validation_split = 0.1
weight_decay = 0.0001
label_smoothing = 0.1

# %%
def window_partition(x, window_size):
    _, height, width, channels = x.shape
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        x, shape=(-1, patch_num_y, window_size, patch_num_x, window_size, channels)
    )
    x = tf.transpose(x, (0, 1, 3, 2, 4, 5))
    windows = tf.reshape(x, shape=(-1, window_size, window_size, channels))
    return windows


def window_reverse(windows, window_size, height, width, channels):
    patch_num_y = height // window_size
    patch_num_x = width // window_size
    x = tf.reshape(
        windows,
        shape=(-1, patch_num_y, patch_num_x, window_size, window_size, channels),
    )
    x = tf.transpose(x, perm=(0, 1, 3, 2, 4, 5))
    x = tf.reshape(x, shape=(-1, height, width, channels))
    return x


class DropPath(layers.Layer):
    def __init__(self, drop_prob=None, **kwargs):
        super().__init__(**kwargs)
        self.drop_prob = drop_prob

    def call(self, x):
        input_shape = tf.shape(x)
        batch_size = input_shape[0]
        rank = x.shape.rank
        shape = (batch_size,) + (1,) * (rank - 1)
        random_tensor = (1 - self.drop_prob) + tf.random.uniform(shape, dtype=x.dtype)
        path_mask = tf.floor(random_tensor)
        output = tf.math.divide(x, 1 - self.drop_prob) * path_mask
        return output

# %%
class WindowAttention(layers.Layer):
    def __init__(
        self, dim, window_size, num_heads, qkv_bias=True, dropout_rate=0.0, **kwargs
    ):
        super().__init__(**kwargs)
        self.dim = dim
        self.window_size = window_size
        self.num_heads = num_heads
        self.scale = (dim // num_heads) ** -0.5
        self.qkv = layers.Dense(dim * 3, use_bias=qkv_bias)
        self.dropout = layers.Dropout(dropout_rate)
        self.proj = layers.Dense(dim)

    def build(self, input_shape):
        num_window_elements = (2 * self.window_size[0] - 1) * (
            2 * self.window_size[1] - 1
        )
        self.relative_position_bias_table = self.add_weight(
            shape=(num_window_elements, self.num_heads),
            initializer=tf.initializers.Zeros(),
            trainable=True,
        )
        coords_h = np.arange(self.window_size[0])
        coords_w = np.arange(self.window_size[1])
        coords_matrix = np.meshgrid(coords_h, coords_w, indexing="ij")
        coords = np.stack(coords_matrix)
        coords_flatten = coords.reshape(2, -1)
        relative_coords = coords_flatten[:, :, None] - coords_flatten[:, None, :]
        relative_coords = relative_coords.transpose([1, 2, 0])
        relative_coords[:, :, 0] += self.window_size[0] - 1
        relative_coords[:, :, 1] += self.window_size[1] - 1
        relative_coords[:, :, 0] *= 2 * self.window_size[1] - 1
        relative_position_index = relative_coords.sum(-1)

        self.relative_position_index = tf.Variable(
            initial_value=tf.convert_to_tensor(relative_position_index), trainable=False
        )

    def call(self, x, mask=None):
        _, size, channels = x.shape
        head_dim = channels // self.num_heads
        x_qkv = self.qkv(x)
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, 3, self.num_heads, head_dim))
        x_qkv = tf.transpose(x_qkv, perm=(2, 0, 3, 1, 4))
        q, k, v = x_qkv[0], x_qkv[1], x_qkv[2]
        q = q * self.scale
        k = tf.transpose(k, perm=(0, 1, 3, 2))
        attn = q @ k

        num_window_elements = self.window_size[0] * self.window_size[1]
        relative_position_index_flat = tf.reshape(
            self.relative_position_index, shape=(-1,)
        )
        relative_position_bias = tf.gather(
            self.relative_position_bias_table, relative_position_index_flat
        )
        relative_position_bias = tf.reshape(
            relative_position_bias, shape=(num_window_elements, num_window_elements, -1)
        )
        relative_position_bias = tf.transpose(relative_position_bias, perm=(2, 0, 1))
        attn = attn + tf.expand_dims(relative_position_bias, axis=0)

        if mask is not None:
            nW = mask.get_shape()[0]
            mask_float = tf.cast(
                tf.expand_dims(tf.expand_dims(mask, axis=1), axis=0), tf.float32
            )
            attn = (
                tf.reshape(attn, shape=(-1, nW, self.num_heads, size, size))
                + mask_float
            )
            attn = tf.reshape(attn, shape=(-1, self.num_heads, size, size))
            attn = keras.activations.softmax(attn, axis=-1)
        else:
            attn = keras.activations.softmax(attn, axis=-1)
        attn = self.dropout(attn)

        x_qkv = attn @ v
        x_qkv = tf.transpose(x_qkv, perm=(0, 2, 1, 3))
        x_qkv = tf.reshape(x_qkv, shape=(-1, size, channels))
        x_qkv = self.proj(x_qkv)
        x_qkv = self.dropout(x_qkv)
        return x_qkv

# %%
class SwinTransformer(layers.Layer):
    def __init__(
        self,
        dim,
        num_patch,
        num_heads,
        window_size=7,
        shift_size=0,
        num_mlp=1024,
        qkv_bias=True,
        dropout_rate=0.0,
        **kwargs,
    ):
        super().__init__(**kwargs)

        self.dim = dim  # number of input dimensions
        self.num_patch = num_patch  # number of embedded patches
        self.num_heads = num_heads  # number of attention heads
        self.window_size = window_size  # size of window
        self.shift_size = shift_size  # size of window shift
        self.num_mlp = num_mlp  # number of MLP nodes

        self.norm1 = layers.LayerNormalization(epsilon=1e-5)
        self.attn = WindowAttention(
            dim,
            window_size=(self.window_size, self.window_size),
            num_heads=num_heads,
            qkv_bias=qkv_bias,
            dropout_rate=dropout_rate,
        )
        self.drop_path = DropPath(dropout_rate)
        self.norm2 = layers.LayerNormalization(epsilon=1e-5)

        self.mlp = keras.Sequential(
            [
                layers.Dense(num_mlp),
                layers.Activation(keras.activations.gelu),
                layers.Dropout(dropout_rate),
                layers.Dense(dim),
                layers.Dropout(dropout_rate),
            ]
        )

        if min(self.num_patch) < self.window_size:
            self.shift_size = 0
            self.window_size = min(self.num_patch)

    def build(self, input_shape):
        if self.shift_size == 0:
            self.attn_mask = None
        else:
            height, width = self.num_patch
            h_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            w_slices = (
                slice(0, -self.window_size),
                slice(-self.window_size, -self.shift_size),
                slice(-self.shift_size, None),
            )
            mask_array = np.zeros((1, height, width, 1))
            count = 0
            for h in h_slices:
                for w in w_slices:
                    mask_array[:, h, w, :] = count
                    count += 1
            mask_array = tf.convert_to_tensor(mask_array)

            # mask array to windows
            mask_windows = window_partition(mask_array, self.window_size)
            mask_windows = tf.reshape(
                mask_windows, shape=[-1, self.window_size * self.window_size]
            )
            attn_mask = tf.expand_dims(mask_windows, axis=1) - tf.expand_dims(
                mask_windows, axis=2
            )
            attn_mask = tf.where(attn_mask != 0, -100.0, attn_mask)
            attn_mask = tf.where(attn_mask == 0, 0.0, attn_mask)
            self.attn_mask = tf.Variable(initial_value=attn_mask, trainable=False)

    def call(self, x):
        height, width = self.num_patch
        _, num_patches_before, channels = x.shape
        x_skip = x
        x = self.norm1(x)
        x = tf.reshape(x, shape=(-1, height, width, channels))
        if self.shift_size > 0:
            shifted_x = tf.roll(
                x, shift=[-self.shift_size, -self.shift_size], axis=[1, 2]
            )
        else:
            shifted_x = x

        x_windows = window_partition(shifted_x, self.window_size)
        x_windows = tf.reshape(
            x_windows, shape=(-1, self.window_size * self.window_size, channels)
        )
        attn_windows = self.attn(x_windows, mask=self.attn_mask)

        attn_windows = tf.reshape(
            attn_windows, shape=(-1, self.window_size, self.window_size, channels)
        )
        shifted_x = window_reverse(
            attn_windows, self.window_size, height, width, channels
        )
        if self.shift_size > 0:
            x = tf.roll(
                shifted_x, shift=[self.shift_size, self.shift_size], axis=[1, 2]
            )
        else:
            x = shifted_x

        x = tf.reshape(x, shape=(-1, height * width, channels))
        x = self.drop_path(x)
        x = x_skip + x
        x_skip = x
        x = self.norm2(x)
        x = self.mlp(x)
        x = self.drop_path(x)
        x = x_skip + x
        return x

# %%
class PatchExtract(layers.Layer):
    def __init__(self, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.patch_size_x = patch_size[0]
        self.patch_size_y = patch_size[0]

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=(1, self.patch_size_x, self.patch_size_y, 1),
            strides=(1, self.patch_size_x, self.patch_size_y, 1),
            rates=(1, 1, 1, 1),
            padding="VALID",
        )
        patch_dim = patches.shape[-1]
        patch_num = patches.shape[1]
        return tf.reshape(patches, (batch_size, patch_num * patch_num, patch_dim))


class PatchEmbedding(layers.Layer):
    def __init__(self, num_patch, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.num_patch = num_patch
        self.proj = layers.Dense(embed_dim)
        self.pos_embed = layers.Embedding(input_dim=num_patch, output_dim=embed_dim)

    def call(self, patch):
        pos = tf.range(start=0, limit=self.num_patch, delta=1)
        return self.proj(patch) + self.pos_embed(pos)


class PatchMerging(tf.keras.layers.Layer):
    def __init__(self, num_patch, embed_dim):
        super().__init__()
        self.num_patch = num_patch
        self.embed_dim = embed_dim
        self.linear_trans = layers.Dense(2 * embed_dim, use_bias=False)

    def call(self, x):
        height, width = self.num_patch
        _, _, C = x.get_shape().as_list()
        x = tf.reshape(x, shape=(-1, height, width, C))
        x0 = x[:, 0::2, 0::2, :]
        x1 = x[:, 1::2, 0::2, :]
        x2 = x[:, 0::2, 1::2, :]
        x3 = x[:, 1::2, 1::2, :]
        x = tf.concat((x0, x1, x2, x3), axis=-1)
        x = tf.reshape(x, shape=(-1, (height // 2) * (width // 2), 4 * C))
        return self.linear_trans(x)

# %%
input = layers.Input(input_shape)
x = layers.RandomCrop(image_dimension, image_dimension)(input)
x = layers.RandomFlip("horizontal")(x)
x = PatchExtract(patch_size)(x)
x = PatchEmbedding(num_patch_x * num_patch_y, embed_dim)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=0,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = SwinTransformer(
    dim=embed_dim,
    num_patch=(num_patch_x, num_patch_y),
    num_heads=num_heads,
    window_size=window_size,
    shift_size=shift_size,
    num_mlp=num_mlp,
    qkv_bias=qkv_bias,
    dropout_rate=dropout_rate,
)(x)
x = PatchMerging((num_patch_x, num_patch_y), embed_dim=embed_dim)(x)
x = layers.GlobalAveragePooling1D()(x)
output = layers.Dense(num_classes, activation="softmax")(x)

# %%
model = keras.Model(input, output)
model.compile(
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=label_smoothing),
    optimizer=tfa.optimizers.AdamW(
        learning_rate=learning_rate, weight_decay=weight_decay
    ),
    metrics=[
        keras.metrics.CategoricalAccuracy(name="accuracy"),
        keras.metrics.TopKCategoricalAccuracy(5, name="top-5-accuracy"),
    ],
)

history = model.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=num_epochs,
    validation_split=validation_split,
)
# Out:
# Epoch 1/100
# 44/44 [==============================] - 9s 89ms/step - loss: 4.3747 - accuracy: 0.0739 - top-5-accuracy: 0.2347 - val_loss: 4.1150 - val_accuracy: 0.0959 - val_top-5-accuracy: 0.2780
# Epoch 2/100
# 44/44 [==============================] - 3s 68ms/step - loss: 3.8794 - accuracy: 0.1411 - top-5-accuracy: 0.3764 - val_loss: 3.7696 - val_accuracy: 0.1626 - val_top-5-accuracy: 0.4114
# Epoch 3/100
# 44/44 [==============================] - 3s 72ms/step - loss: 3.6147 - accuracy: 0.1984 - top-5-accuracy: 0.4597 - val_loss: 3.5622 - val_accuracy: 0.2049 - val_top-5-accuracy: 0.4911
# Epoch 4/100
# 44/44 [==============================] - 3s 73ms/step - loss: 3.3882 - accuracy: 0.2539 - top-5-accuracy: 0.5372 - val_loss: 3.4672 - val_accuracy: 0.2000 - val_top-5-accuracy: 0.5187
# Epoch 5/100
# 44/44 [==============================] - 3s 75ms/step - loss: 3.2554 - accuracy: 0.2940 - top-5-accuracy: 0.5748 - val_loss: 3.2928 - val_accuracy: 0.2553 - val_top-5-accuracy: 0.5691
# Epoch 6/100
# 44/44 [==============================] - 3s 76ms/step - loss: 3.1175 - accuracy: 0.3253 - top-5-accuracy: 0.6194 - val_loss: 3.2077 - val_accuracy: 0.2927 - val_top-5-accuracy: 0.5870
# Epoch 7/100
# 44/44 [==============================] - 3s 70ms/step - loss: 3.0410 - accuracy: 0.3419 - top-5-accuracy: 0.6482 - val_loss: 3.1134 - val_accuracy: 0.3024 - val_top-5-accuracy: 0.5984
# Epoch 8/100
# 44/44 [==============================] - 3s 68ms/step - loss: 2.9278 - accuracy: 0.3730 - top-5-accuracy: 0.6756 - val_loss: 3.1283 - val_accuracy: 0.3236 - val_top-5-accuracy: 0.6114
# Epoch 9/100
# 44/44 [==============================] - 3s 68ms/step - loss: 2.8991 - accuracy: 0.3898 - top-5-accuracy: 0.6847 - val_loss: 2.9757 - val_accuracy: 0.3789 - val_top-5-accuracy: 0.6569
# Epoch 10/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.8072 - accuracy: 0.4026 - top-5-accuracy: 0.7105 - val_loss: 2.9517 - val_accuracy: 0.3691 - val_top-5-accuracy: 0.6667
# Epoch 11/100
# 44/44 [==============================] - 3s 70ms/step - loss: 2.7448 - accuracy: 0.4310 - top-5-accuracy: 0.7329 - val_loss: 2.8615 - val_accuracy: 0.3886 - val_top-5-accuracy: 0.6878
# Epoch 12/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.6589 - accuracy: 0.4575 - top-5-accuracy: 0.7492 - val_loss: 2.8120 - val_accuracy: 0.3919 - val_top-5-accuracy: 0.7171
# Epoch 13/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.6208 - accuracy: 0.4615 - top-5-accuracy: 0.7671 - val_loss: 2.7781 - val_accuracy: 0.4049 - val_top-5-accuracy: 0.7301
# Epoch 14/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.5677 - accuracy: 0.4772 - top-5-accuracy: 0.7761 - val_loss: 2.6986 - val_accuracy: 0.4146 - val_top-5-accuracy: 0.7366
# Epoch 15/100
# 44/44 [==============================] - 3s 70ms/step - loss: 2.5324 - accuracy: 0.4939 - top-5-accuracy: 0.7873 - val_loss: 2.8131 - val_accuracy: 0.3935 - val_top-5-accuracy: 0.7285
# Epoch 16/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.5217 - accuracy: 0.4939 - top-5-accuracy: 0.7853 - val_loss: 2.7095 - val_accuracy: 0.4276 - val_top-5-accuracy: 0.7203
# Epoch 17/100
# 44/44 [==============================] - 3s 68ms/step - loss: 2.4354 - accuracy: 0.5193 - top-5-accuracy: 0.8076 - val_loss: 2.7009 - val_accuracy: 0.4407 - val_top-5-accuracy: 0.7431
# Epoch 18/100
# 44/44 [==============================] - 3s 68ms/step - loss: 2.4036 - accuracy: 0.5356 - top-5-accuracy: 0.8106 - val_loss: 2.6068 - val_accuracy: 0.4585 - val_top-5-accuracy: 0.7756
# Epoch 19/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.3456 - accuracy: 0.5497 - top-5-accuracy: 0.8256 - val_loss: 2.5709 - val_accuracy: 0.4699 - val_top-5-accuracy: 0.7626
# Epoch 20/100
# 44/44 [==============================] - 3s 71ms/step - loss: 2.3545 - accuracy: 0.5492 - top-5-accuracy: 0.8276 - val_loss: 2.6181 - val_accuracy: 0.4748 - val_top-5-accuracy: 0.7756
# Epoch 21/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.3253 - accuracy: 0.5573 - top-5-accuracy: 0.8350 - val_loss: 2.5455 - val_accuracy: 0.4943 - val_top-5-accuracy: 0.7886
# Epoch 22/100
# 44/44 [==============================] - 3s 68ms/step - loss: 2.2670 - accuracy: 0.5741 - top-5-accuracy: 0.8426 - val_loss: 2.5512 - val_accuracy: 0.4585 - val_top-5-accuracy: 0.7951
# Epoch 23/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.2416 - accuracy: 0.5811 - top-5-accuracy: 0.8498 - val_loss: 2.5093 - val_accuracy: 0.5041 - val_top-5-accuracy: 0.7902
# Epoch 24/100
# 44/44 [==============================] - 3s 68ms/step - loss: 2.2253 - accuracy: 0.5826 - top-5-accuracy: 0.8529 - val_loss: 2.4619 - val_accuracy: 0.4911 - val_top-5-accuracy: 0.7935
# Epoch 25/100
# 44/44 [==============================] - 3s 68ms/step - loss: 2.1893 - accuracy: 0.5992 - top-5-accuracy: 0.8681 - val_loss: 2.4967 - val_accuracy: 0.5024 - val_top-5-accuracy: 0.8130
# Epoch 26/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.1880 - accuracy: 0.5999 - top-5-accuracy: 0.8648 - val_loss: 2.5175 - val_accuracy: 0.4699 - val_top-5-accuracy: 0.8016
# Epoch 27/100
# 44/44 [==============================] - 3s 70ms/step - loss: 2.1695 - accuracy: 0.6021 - top-5-accuracy: 0.8625 - val_loss: 2.4643 - val_accuracy: 0.5171 - val_top-5-accuracy: 0.8065
# Epoch 28/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.1070 - accuracy: 0.6274 - top-5-accuracy: 0.8780 - val_loss: 2.4408 - val_accuracy: 0.5089 - val_top-5-accuracy: 0.8049
# Epoch 29/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.0795 - accuracy: 0.6312 - top-5-accuracy: 0.8851 - val_loss: 2.5053 - val_accuracy: 0.4894 - val_top-5-accuracy: 0.8081
# Epoch 30/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.0721 - accuracy: 0.6438 - top-5-accuracy: 0.8829 - val_loss: 2.4927 - val_accuracy: 0.4992 - val_top-5-accuracy: 0.8065
# Epoch 31/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.0558 - accuracy: 0.6431 - top-5-accuracy: 0.8838 - val_loss: 2.4419 - val_accuracy: 0.5285 - val_top-5-accuracy: 0.8179
# Epoch 32/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.0429 - accuracy: 0.6547 - top-5-accuracy: 0.8894 - val_loss: 2.5203 - val_accuracy: 0.5089 - val_top-5-accuracy: 0.8016
# Epoch 33/100
# 44/44 [==============================] - 3s 69ms/step - loss: 2.0445 - accuracy: 0.6429 - top-5-accuracy: 0.8943 - val_loss: 2.4015 - val_accuracy: 0.5366 - val_top-5-accuracy: 0.8146
# Epoch 34/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.9987 - accuracy: 0.6637 - top-5-accuracy: 0.9017 - val_loss: 2.3722 - val_accuracy: 0.5301 - val_top-5-accuracy: 0.8293
# Epoch 35/100
# 44/44 [==============================] - 3s 70ms/step - loss: 1.9810 - accuracy: 0.6722 - top-5-accuracy: 0.9019 - val_loss: 2.4385 - val_accuracy: 0.5236 - val_top-5-accuracy: 0.8228
# Epoch 36/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.9690 - accuracy: 0.6780 - top-5-accuracy: 0.9060 - val_loss: 2.4426 - val_accuracy: 0.5333 - val_top-5-accuracy: 0.8016
# Epoch 37/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.9734 - accuracy: 0.6794 - top-5-accuracy: 0.9066 - val_loss: 2.4177 - val_accuracy: 0.5268 - val_top-5-accuracy: 0.8309
# Epoch 38/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.9229 - accuracy: 0.6932 - top-5-accuracy: 0.9125 - val_loss: 2.4900 - val_accuracy: 0.5122 - val_top-5-accuracy: 0.8033
# Epoch 39/100
# 44/44 [==============================] - 3s 70ms/step - loss: 1.9101 - accuracy: 0.7027 - top-5-accuracy: 0.9142 - val_loss: 2.5093 - val_accuracy: 0.5154 - val_top-5-accuracy: 0.8065
# Epoch 40/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.9155 - accuracy: 0.6932 - top-5-accuracy: 0.9134 - val_loss: 2.3607 - val_accuracy: 0.5398 - val_top-5-accuracy: 0.8325
# Epoch 41/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.8896 - accuracy: 0.7093 - top-5-accuracy: 0.9201 - val_loss: 2.3763 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.8260
# Epoch 42/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.8768 - accuracy: 0.7089 - top-5-accuracy: 0.9205 - val_loss: 2.4044 - val_accuracy: 0.5447 - val_top-5-accuracy: 0.8228
# Epoch 43/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.8623 - accuracy: 0.7177 - top-5-accuracy: 0.9245 - val_loss: 2.4226 - val_accuracy: 0.5528 - val_top-5-accuracy: 0.8195
# Epoch 44/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.8502 - accuracy: 0.7239 - top-5-accuracy: 0.9277 - val_loss: 2.3933 - val_accuracy: 0.5447 - val_top-5-accuracy: 0.8244
# Epoch 45/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.8140 - accuracy: 0.7338 - top-5-accuracy: 0.9312 - val_loss: 2.4355 - val_accuracy: 0.5268 - val_top-5-accuracy: 0.8146
# Epoch 46/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.8054 - accuracy: 0.7336 - top-5-accuracy: 0.9346 - val_loss: 2.3674 - val_accuracy: 0.5480 - val_top-5-accuracy: 0.8211
# Epoch 47/100
# 44/44 [==============================] - 3s 70ms/step - loss: 1.7859 - accuracy: 0.7447 - top-5-accuracy: 0.9355 - val_loss: 2.3410 - val_accuracy: 0.5496 - val_top-5-accuracy: 0.8325
# Epoch 48/100
# 44/44 [==============================] - 3s 71ms/step - loss: 1.7994 - accuracy: 0.7318 - top-5-accuracy: 0.9355 - val_loss: 2.3744 - val_accuracy: 0.5382 - val_top-5-accuracy: 0.8439
# Epoch 49/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.7864 - accuracy: 0.7438 - top-5-accuracy: 0.9371 - val_loss: 2.3673 - val_accuracy: 0.5447 - val_top-5-accuracy: 0.8211
# Epoch 50/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.7746 - accuracy: 0.7449 - top-5-accuracy: 0.9351 - val_loss: 2.3138 - val_accuracy: 0.5805 - val_top-5-accuracy: 0.8374
# Epoch 51/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.7414 - accuracy: 0.7606 - top-5-accuracy: 0.9413 - val_loss: 2.3567 - val_accuracy: 0.5545 - val_top-5-accuracy: 0.8374
# Epoch 52/100
# 44/44 [==============================] - 3s 70ms/step - loss: 1.7512 - accuracy: 0.7568 - top-5-accuracy: 0.9425 - val_loss: 2.3344 - val_accuracy: 0.5593 - val_top-5-accuracy: 0.8520
# Epoch 53/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.7407 - accuracy: 0.7561 - top-5-accuracy: 0.9420 - val_loss: 2.3106 - val_accuracy: 0.5837 - val_top-5-accuracy: 0.8407
# Epoch 54/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.7153 - accuracy: 0.7685 - top-5-accuracy: 0.9492 - val_loss: 2.3170 - val_accuracy: 0.5740 - val_top-5-accuracy: 0.8407
# Epoch 55/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.7235 - accuracy: 0.7696 - top-5-accuracy: 0.9420 - val_loss: 2.3437 - val_accuracy: 0.5789 - val_top-5-accuracy: 0.8325
# Epoch 56/100
# 44/44 [==============================] - 3s 70ms/step - loss: 1.7434 - accuracy: 0.7562 - top-5-accuracy: 0.9407 - val_loss: 2.4076 - val_accuracy: 0.5366 - val_top-5-accuracy: 0.8211
# Epoch 57/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.7102 - accuracy: 0.7790 - top-5-accuracy: 0.9434 - val_loss: 2.3099 - val_accuracy: 0.5789 - val_top-5-accuracy: 0.8293
# Epoch 58/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.7025 - accuracy: 0.7795 - top-5-accuracy: 0.9451 - val_loss: 2.3101 - val_accuracy: 0.5772 - val_top-5-accuracy: 0.8358
# Epoch 59/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.6645 - accuracy: 0.7904 - top-5-accuracy: 0.9539 - val_loss: 2.3917 - val_accuracy: 0.5675 - val_top-5-accuracy: 0.8228
# Epoch 60/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.6564 - accuracy: 0.7969 - top-5-accuracy: 0.9519 - val_loss: 2.3361 - val_accuracy: 0.5561 - val_top-5-accuracy: 0.8407
# Epoch 61/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.6629 - accuracy: 0.7833 - top-5-accuracy: 0.9546 - val_loss: 2.4605 - val_accuracy: 0.5317 - val_top-5-accuracy: 0.8228
# Epoch 62/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.6599 - accuracy: 0.7886 - top-5-accuracy: 0.9519 - val_loss: 2.3473 - val_accuracy: 0.5528 - val_top-5-accuracy: 0.8163
# Epoch 63/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.6386 - accuracy: 0.8012 - top-5-accuracy: 0.9543 - val_loss: 2.3352 - val_accuracy: 0.5967 - val_top-5-accuracy: 0.8390
# Epoch 64/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.6418 - accuracy: 0.7983 - top-5-accuracy: 0.9521 - val_loss: 2.3619 - val_accuracy: 0.5463 - val_top-5-accuracy: 0.8293
# Epoch 65/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.6217 - accuracy: 0.8018 - top-5-accuracy: 0.9610 - val_loss: 2.3254 - val_accuracy: 0.5740 - val_top-5-accuracy: 0.8374
# Epoch 66/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.6194 - accuracy: 0.8003 - top-5-accuracy: 0.9583 - val_loss: 2.2824 - val_accuracy: 0.6049 - val_top-5-accuracy: 0.8553
# Epoch 67/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.6176 - accuracy: 0.8074 - top-5-accuracy: 0.9592 - val_loss: 2.3523 - val_accuracy: 0.5772 - val_top-5-accuracy: 0.8455
# Epoch 68/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.5983 - accuracy: 0.8193 - top-5-accuracy: 0.9579 - val_loss: 2.3580 - val_accuracy: 0.5740 - val_top-5-accuracy: 0.8293
# Epoch 69/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.6104 - accuracy: 0.8094 - top-5-accuracy: 0.9617 - val_loss: 2.3338 - val_accuracy: 0.5642 - val_top-5-accuracy: 0.8341
# Epoch 70/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.5795 - accuracy: 0.8211 - top-5-accuracy: 0.9630 - val_loss: 2.2420 - val_accuracy: 0.5984 - val_top-5-accuracy: 0.8585
# Epoch 71/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.5933 - accuracy: 0.8191 - top-5-accuracy: 0.9637 - val_loss: 2.3336 - val_accuracy: 0.5659 - val_top-5-accuracy: 0.8439
# Epoch 72/100
# 44/44 [==============================] - 3s 76ms/step - loss: 1.5790 - accuracy: 0.8236 - top-5-accuracy: 0.9631 - val_loss: 2.3220 - val_accuracy: 0.5675 - val_top-5-accuracy: 0.8472
# Epoch 73/100
# 44/44 [==============================] - 3s 74ms/step - loss: 1.5549 - accuracy: 0.8289 - top-5-accuracy: 0.9621 - val_loss: 2.2718 - val_accuracy: 0.5789 - val_top-5-accuracy: 0.8439
# Epoch 74/100
# 44/44 [==============================] - 3s 73ms/step - loss: 1.5626 - accuracy: 0.8233 - top-5-accuracy: 0.9660 - val_loss: 2.2756 - val_accuracy: 0.5935 - val_top-5-accuracy: 0.8455
# Epoch 75/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.5662 - accuracy: 0.8247 - top-5-accuracy: 0.9628 - val_loss: 2.3082 - val_accuracy: 0.5740 - val_top-5-accuracy: 0.8455
# Epoch 76/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.5583 - accuracy: 0.8303 - top-5-accuracy: 0.9635 - val_loss: 2.3385 - val_accuracy: 0.5675 - val_top-5-accuracy: 0.8260
# Epoch 77/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.5367 - accuracy: 0.8397 - top-5-accuracy: 0.9678 - val_loss: 2.2878 - val_accuracy: 0.5886 - val_top-5-accuracy: 0.8537
# Epoch 78/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.5422 - accuracy: 0.8361 - top-5-accuracy: 0.9684 - val_loss: 2.3175 - val_accuracy: 0.5626 - val_top-5-accuracy: 0.8358
# Epoch 79/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.5181 - accuracy: 0.8441 - top-5-accuracy: 0.9713 - val_loss: 2.3255 - val_accuracy: 0.5919 - val_top-5-accuracy: 0.8390
# Epoch 80/100
# 44/44 [==============================] - 3s 70ms/step - loss: 1.5138 - accuracy: 0.8457 - top-5-accuracy: 0.9733 - val_loss: 2.2654 - val_accuracy: 0.6098 - val_top-5-accuracy: 0.8407
# Epoch 81/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.5269 - accuracy: 0.8422 - top-5-accuracy: 0.9698 - val_loss: 2.3126 - val_accuracy: 0.5886 - val_top-5-accuracy: 0.8423
# Epoch 82/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.5157 - accuracy: 0.8471 - top-5-accuracy: 0.9705 - val_loss: 2.3436 - val_accuracy: 0.5740 - val_top-5-accuracy: 0.8228
# Epoch 83/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.5123 - accuracy: 0.8424 - top-5-accuracy: 0.9720 - val_loss: 2.3082 - val_accuracy: 0.5756 - val_top-5-accuracy: 0.8488
# Epoch 84/100
# 44/44 [==============================] - 3s 70ms/step - loss: 1.4926 - accuracy: 0.8545 - top-5-accuracy: 0.9713 - val_loss: 2.2931 - val_accuracy: 0.5854 - val_top-5-accuracy: 0.8309
# Epoch 85/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.4974 - accuracy: 0.8533 - top-5-accuracy: 0.9734 - val_loss: 2.3278 - val_accuracy: 0.5626 - val_top-5-accuracy: 0.8325
# Epoch 86/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4953 - accuracy: 0.8560 - top-5-accuracy: 0.9698 - val_loss: 2.2809 - val_accuracy: 0.5951 - val_top-5-accuracy: 0.8520
# Epoch 87/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4883 - accuracy: 0.8547 - top-5-accuracy: 0.9727 - val_loss: 2.3063 - val_accuracy: 0.5707 - val_top-5-accuracy: 0.8488
# Epoch 88/100
# 44/44 [==============================] - 3s 73ms/step - loss: 1.4754 - accuracy: 0.8616 - top-5-accuracy: 0.9718 - val_loss: 2.2714 - val_accuracy: 0.5821 - val_top-5-accuracy: 0.8455
# Epoch 89/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4703 - accuracy: 0.8665 - top-5-accuracy: 0.9740 - val_loss: 2.3556 - val_accuracy: 0.5707 - val_top-5-accuracy: 0.8390
# Epoch 90/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.4640 - accuracy: 0.8623 - top-5-accuracy: 0.9749 - val_loss: 2.2825 - val_accuracy: 0.5951 - val_top-5-accuracy: 0.8260
# Epoch 91/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.4783 - accuracy: 0.8625 - top-5-accuracy: 0.9714 - val_loss: 2.2481 - val_accuracy: 0.6065 - val_top-5-accuracy: 0.8423
# Epoch 92/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4626 - accuracy: 0.8679 - top-5-accuracy: 0.9736 - val_loss: 2.2387 - val_accuracy: 0.6114 - val_top-5-accuracy: 0.8341
# Epoch 93/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4627 - accuracy: 0.8692 - top-5-accuracy: 0.9734 - val_loss: 2.2434 - val_accuracy: 0.5951 - val_top-5-accuracy: 0.8407
# Epoch 94/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.4605 - accuracy: 0.8694 - top-5-accuracy: 0.9736 - val_loss: 2.2425 - val_accuracy: 0.6260 - val_top-5-accuracy: 0.8439
# Epoch 95/100
# 44/44 [==============================] - 3s 68ms/step - loss: 1.4403 - accuracy: 0.8708 - top-5-accuracy: 0.9798 - val_loss: 2.2737 - val_accuracy: 0.5919 - val_top-5-accuracy: 0.8634
# Epoch 96/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4374 - accuracy: 0.8766 - top-5-accuracy: 0.9756 - val_loss: 2.3369 - val_accuracy: 0.5870 - val_top-5-accuracy: 0.8407
# Epoch 97/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4530 - accuracy: 0.8666 - top-5-accuracy: 0.9740 - val_loss: 2.2842 - val_accuracy: 0.5902 - val_top-5-accuracy: 0.8455
# Epoch 98/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4187 - accuracy: 0.8836 - top-5-accuracy: 0.9774 - val_loss: 2.2144 - val_accuracy: 0.6163 - val_top-5-accuracy: 0.8585
# Epoch 99/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4173 - accuracy: 0.8804 - top-5-accuracy: 0.9774 - val_loss: 2.2739 - val_accuracy: 0.6081 - val_top-5-accuracy: 0.8374
# Epoch 100/100
# 44/44 [==============================] - 3s 69ms/step - loss: 1.4110 - accuracy: 0.8822 - top-5-accuracy: 0.9801 - val_loss: 2.2737 - val_accuracy: 0.6000 - val_top-5-accuracy: 0.8358

# %%
plt.plot(history.history["loss"], label="train_loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

plt.plot(history.history["accuracy"], label="test_accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation accuracies Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
y_pred = model.predict(x_test)
predicted_ids = np.argmax(y_pred, axis=-1)
true_classes = np.argmax(y_test, axis=-1)
accuracy = np.mean(predicted_ids == true_classes)
print('Precisão:', accuracy)
# Out:
# 32/32 [==============================] - 0s 12ms/step
# Precisão: 0.5294117647058824

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report

# Calcular a precisão, recall e F1-score para cada classe
report = classification_report(true_classes, predicted_ids, target_names=np.array(info.features['label'].names))

# Exibir o relatório de classificação
print(report)
# Out:
#                            precision    recall  f1-score   support
#
#             pink primrose       0.75      0.60      0.67        10
# hard-leaved pocket orchid       0.88      0.70      0.78        10
#          canterbury bells       0.50      0.20      0.29        10
#                 sweet pea       0.00      0.00      0.00        10
#          english marigold       0.67      0.20      0.31        10
#                tiger lily       0.57      0.40      0.47        10
#               moon orchid       1.00      0.30      0.46        10
#          bird of paradise       0.78      0.70      0.74        10
#                 monkshood       0.80      0.40      0.53        10
#             globe thistle       0.69      0.90      0.78        10
#                snapdragon       0.25      0.20      0.22        10
#               colt's foot       0.44      0.80      0.57        10
#               king protea       0.86      0.60      0.71        10
#             spear thistle       0.90      0.90      0.90        10
#               yellow iris       0.40      0.40      0.40        10
#              globe-flower       0.50      0.10      0.17        10
#         purple coneflower       0.89      0.80      0.84        10
#             peruvian lily       0.50      0.30      0.37        10
#            balloon flower       0.33      0.20      0.25        10
#     giant white arum lily       0.64      0.70      0.67        10
#                 fire lily       1.00      0.30      0.46        10
#         pincushion flower       1.00      0.60      0.75        10
#                fritillary       0.60      0.60      0.60        10
#                red ginger       0.44      0.40      0.42        10
#            grape hyacinth       0.57      0.40      0.47        10
#                corn poppy       1.00      0.50      0.67        10
#  prince of wales feathers       1.00      0.30      0.46        10
#          stemless gentian       0.43      0.90      0.58        10
#                 artichoke       0.41      0.90      0.56        10
#             sweet william       0.36      0.40      0.38        10
#                 carnation       0.17      0.10      0.12        10
#              garden phlox       0.40      0.20      0.27        10
#          love in the mist       0.67      0.40      0.50        10
#             mexican aster       0.71      0.50      0.59        10
#          alpine sea holly       0.60      0.60      0.60        10
#      ruby-lipped cattleya       1.00      0.20      0.33        10
#               cape flower       0.89      0.80      0.84        10
#          great masterwort       0.71      0.50      0.59        10
#                siam tulip       0.60      0.60      0.60        10
#               lenten rose       0.64      0.70      0.67        10
#            barbeton daisy       0.33      0.40      0.36        10
#                  daffodil       0.50      0.10      0.17        10
#                sword lily       0.10      0.10      0.10        10
#                poinsettia       0.40      0.40      0.40        10
#          bolero deep blue       0.67      0.40      0.50        10
#                wallflower       0.60      0.90      0.72        10
#                  marigold       0.73      0.80      0.76        10
#                 buttercup       0.38      0.50      0.43        10
#               oxeye daisy       0.75      0.60      0.67        10
#          common dandelion       0.47      0.70      0.56        10
#                   petunia       0.20      0.90      0.33        10
#                wild pansy       0.60      0.90      0.72        10
#                   primula       0.40      0.40      0.40        10
#                 sunflower       0.67      0.40      0.50        10
#               pelargonium       0.50      1.00      0.67        10
#        bishop of llandaff       0.71      1.00      0.83        10
#                     gaura       1.00      0.40      0.57        10
#                  geranium       0.77      1.00      0.87        10
#             orange dahlia       0.57      0.80      0.67        10
#       pink-yellow dahlia?       0.71      1.00      0.83        10
#          cautleya spicata       0.77      1.00      0.87        10
#          japanese anemone       0.60      0.30      0.40        10
#          black-eyed susan       1.00      1.00      1.00        10
#                silverbush       0.75      0.90      0.82        10
#         californian poppy       0.56      1.00      0.71        10
#              osteospermum       0.80      0.80      0.80        10
#             spring crocus       0.00      0.00      0.00        10
#              bearded iris       1.00      0.50      0.67        10
#                windflower       0.50      0.50      0.50        10
#                tree poppy       0.50      0.50      0.50        10
#                   gazania       0.91      1.00      0.95        10
#                    azalea       0.22      0.20      0.21        10
#                water lily       0.47      0.80      0.59        10
#                      rose       0.40      0.60      0.48        10
#               thorn apple       0.38      0.90      0.53        10
#             morning glory       0.39      0.70      0.50        10
#            passion flower       0.35      0.60      0.44        10
#                     lotus       0.45      0.50      0.48        10
#                 toad lily       0.60      0.30      0.40        10
#                 anthurium       0.20      0.10      0.13        10
#                frangipani       0.73      0.80      0.76        10
#                  clematis       0.33      0.10      0.15        10
#                  hibiscus       0.36      0.40      0.38        10
#                 columbine       0.40      0.20      0.27        10
#               desert-rose       1.00      0.60      0.75        10
#               tree mallow       0.75      0.90      0.82        10
#                  magnolia       0.80      0.40      0.53        10
#                  cyclamen       0.22      0.60      0.32        10
#                watercress       0.31      0.90      0.46        10
#                canna lily       0.50      0.10      0.17        10
#               hippeastrum       0.75      0.60      0.67        10
#                  bee balm       1.00      0.40      0.57        10
#                 ball moss       0.20      0.10      0.13        10
#                  foxglove       0.31      0.40      0.35        10
#             bougainvillea       0.28      0.50      0.36        10
#                  camellia       0.27      0.30      0.29        10
#                    mallow       0.45      0.50      0.48        10
#           mexican petunia       0.27      0.30      0.29        10
#                  bromelia       0.31      0.40      0.35        10
#            blanket flower       1.00      0.80      0.89        10
#           trumpet creeper       0.75      0.30      0.43        10
#           blackberry lily       0.67      0.20      0.31        10
#
#                  accuracy                           0.53      1020
#                 macro avg       0.58      0.53      0.51      1020
#              weighted avg       0.58      0.53      0.51      1020
