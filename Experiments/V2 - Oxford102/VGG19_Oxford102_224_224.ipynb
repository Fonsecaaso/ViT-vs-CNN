# %%
import itertools
import os

import matplotlib.pylab as plt
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
import tensorflow_datasets as tfds

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.test.is_gpu_available() else "NOT AVAILABLE")
# Out:
# WARNING:tensorflow:From <ipython-input-5-9a8971ee22f7>:15: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# TF version: 2.12.0
# Hub version: 0.13.0
# GPU is available

# %%
module_selection = ("inception_v3", 299) #@param ["(\"mobilenet_v2_100_224\", 224)", "(\"inception_v3\", 299)"] {type:"raw", allow-input: true}
handle_base, pixels = module_selection
MODULE_HANDLE ="https://tfhub.dev/google/imagenet/{}/feature_vector/4".format(handle_base)
IMAGE_SIZE = (pixels, pixels)
print("Using {} with input size {}".format(MODULE_HANDLE, IMAGE_SIZE))

BATCH_SIZE = 16 #@param {type:"integer"}
# Out:
# Using https://tfhub.dev/google/imagenet/inception_v3/feature_vector/4 with input size (299, 299)

# %%
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    name="oxford_flowers102",
    split=['test', 'validation', 'train'],
    with_info=True,
    as_supervised=True,
    batch_size=32
)
# Out:
# Downloading and preparing dataset 328.90 MiB (download: 328.90 MiB, generated: 331.34 MiB, total: 660.25 MiB) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/2.1.1.incompleteJNFG69/oxford_flowers102-train.tfrecord*…
# Generating test examples...:   0%|          | 0/6149 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/2.1.1.incompleteJNFG69/oxford_flowers102-test.tfrecord*.…
# Generating validation examples...:   0%|          | 0/1020 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/2.1.1.incompleteJNFG69/oxford_flowers102-validation.tfre…
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.

# %%
IMAG_SIZE = 224 # All images will be resized to 224x224
def normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  image = tf.cast(image, tf.float32)
  image = (image/127.5) - 1
  image = tf.image.resize(image, (IMAG_SIZE, IMAG_SIZE))
  return  image, label

# %%
train = raw_train.map(normalize_img)
validation = raw_validation.map(normalize_img)
test = raw_test.map(normalize_img)

# %%
# print("Building model with", MODULE_HANDLE)
conv_base = VGG19(include_top=False, weights='imagenet', input_shape=(IMAG_SIZE, IMAG_SIZE,3))
for layer in conv_base.layers:
    layer.trainable = False

model = tf.keras.Sequential([
    conv_base,
    tf.keras.layers.Flatten(name="flatten"),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dense(1072, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(units=metadata.features["label"].num_classes)
])

model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 5s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 4096)              102764544
#
#  dense_1 (Dense)             (None, 1072)              4391984
#
#  dropout (Dropout)           (None, 1072)              0
#
#  dense_2 (Dense)             (None, 102)               109446
#
# =================================================================
# Total params: 127,290,358
# Trainable params: 107,265,974
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint_filepath = "/tmp/checkpoint"
checkpoint_callback = ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
)

earlystopping = EarlyStopping(monitor='val_loss', patience=5)

model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=.5e-3), 
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
train = train.unbatch().batch(BATCH_SIZE,drop_remainder=True).repeat().shuffle(512)
validation = validation.unbatch().batch(BATCH_SIZE,drop_remainder=True).repeat()

# %%
steps_per_epoch = metadata.splits["train"].num_examples / BATCH_SIZE 
validation_steps = metadata.splits["validation"].num_examples / BATCH_SIZE
EPOCHS = 40
hist = model.fit(
    x=train,
    epochs=EPOCHS, steps_per_epoch=steps_per_epoch,
    validation_data=validation,
    validation_steps=validation_steps,
    callbacks=[checkpoint_callback],
    verbose=1).history
# Out:
# Epoch 1/40
# 63/63 [==============================] - 65s 272ms/step - loss: 5.3892 - accuracy: 0.0361 - val_loss: 4.6956 - val_accuracy: 0.0195
# Epoch 2/40
# 63/63 [==============================] - 22s 344ms/step - loss: 4.1452 - accuracy: 0.0967 - val_loss: 4.3022 - val_accuracy: 0.0869
# Epoch 3/40
# 63/63 [==============================] - 22s 343ms/step - loss: 3.6031 - accuracy: 0.1875 - val_loss: 4.0620 - val_accuracy: 0.1523
# Epoch 4/40
# 63/63 [==============================] - 22s 346ms/step - loss: 3.1186 - accuracy: 0.2803 - val_loss: 3.5732 - val_accuracy: 0.2090
# Epoch 5/40
# 63/63 [==============================] - 17s 272ms/step - loss: 2.8043 - accuracy: 0.3213 - val_loss: 3.0987 - val_accuracy: 0.2783
# Epoch 6/40
# 63/63 [==============================] - 22s 351ms/step - loss: 2.3031 - accuracy: 0.4209 - val_loss: 2.6775 - val_accuracy: 0.3330
# Epoch 7/40
# 63/63 [==============================] - 12s 190ms/step - loss: 1.9811 - accuracy: 0.4902 - val_loss: 2.7178 - val_accuracy: 0.3330
# Epoch 8/40
# 63/63 [==============================] - 18s 289ms/step - loss: 1.7830 - accuracy: 0.5342 - val_loss: 2.3386 - val_accuracy: 0.4033
# Epoch 9/40
# 63/63 [==============================] - 22s 348ms/step - loss: 1.6264 - accuracy: 0.5508 - val_loss: 2.0077 - val_accuracy: 0.4756
# Epoch 10/40
# 63/63 [==============================] - 13s 199ms/step - loss: 1.5566 - accuracy: 0.5898 - val_loss: 2.1020 - val_accuracy: 0.4453
# Epoch 11/40
# 63/63 [==============================] - 18s 281ms/step - loss: 1.4468 - accuracy: 0.5840 - val_loss: 1.7536 - val_accuracy: 0.5352
# Epoch 12/40
# 63/63 [==============================] - 12s 192ms/step - loss: 1.0734 - accuracy: 0.6934 - val_loss: 1.7453 - val_accuracy: 0.5312
# Epoch 13/40
# 63/63 [==============================] - 22s 347ms/step - loss: 1.0927 - accuracy: 0.6826 - val_loss: 1.5174 - val_accuracy: 0.5684
# Epoch 14/40
# 63/63 [==============================] - 12s 188ms/step - loss: 0.9016 - accuracy: 0.7422 - val_loss: 1.5664 - val_accuracy: 0.5605
# Epoch 15/40
# 63/63 [==============================] - 17s 277ms/step - loss: 0.9310 - accuracy: 0.7373 - val_loss: 1.4361 - val_accuracy: 0.6055
# Epoch 16/40
# 63/63 [==============================] - 13s 205ms/step - loss: 0.8593 - accuracy: 0.7529 - val_loss: 1.4455 - val_accuracy: 0.5938
# Epoch 17/40
# 63/63 [==============================] - 12s 193ms/step - loss: 0.7909 - accuracy: 0.7764 - val_loss: 1.4649 - val_accuracy: 0.6055
# Epoch 18/40
# 63/63 [==============================] - 16s 259ms/step - loss: 0.7631 - accuracy: 0.7744 - val_loss: 1.5120 - val_accuracy: 0.5908
# Epoch 19/40
# 63/63 [==============================] - 23s 360ms/step - loss: 0.5743 - accuracy: 0.8428 - val_loss: 1.3939 - val_accuracy: 0.6328
# Epoch 20/40
# 63/63 [==============================] - 12s 190ms/step - loss: 0.6521 - accuracy: 0.8047 - val_loss: 1.4413 - val_accuracy: 0.5898
# Epoch 21/40
# 63/63 [==============================] - 18s 287ms/step - loss: 0.6446 - accuracy: 0.8242 - val_loss: 1.2383 - val_accuracy: 0.6572
# Epoch 22/40
# 63/63 [==============================] - 22s 349ms/step - loss: 0.5363 - accuracy: 0.8408 - val_loss: 1.2951 - val_accuracy: 0.6650
# Epoch 23/40
# 63/63 [==============================] - 16s 260ms/step - loss: 0.4016 - accuracy: 0.8721 - val_loss: 1.3124 - val_accuracy: 0.6484
# Epoch 24/40
# 63/63 [==============================] - 12s 196ms/step - loss: 0.4500 - accuracy: 0.8701 - val_loss: 1.3686 - val_accuracy: 0.6250
# Epoch 25/40
# 63/63 [==============================] - 20s 312ms/step - loss: 0.3490 - accuracy: 0.8848 - val_loss: 1.1573 - val_accuracy: 0.6729
# Epoch 26/40
# 63/63 [==============================] - 12s 188ms/step - loss: 0.3847 - accuracy: 0.8926 - val_loss: 1.8803 - val_accuracy: 0.5752
# Epoch 27/40
# 63/63 [==============================] - 12s 190ms/step - loss: 0.4028 - accuracy: 0.8760 - val_loss: 1.2866 - val_accuracy: 0.6631
# Epoch 28/40
# 63/63 [==============================] - 18s 290ms/step - loss: 0.2196 - accuracy: 0.9346 - val_loss: 1.2814 - val_accuracy: 0.6748
# Epoch 29/40
# 63/63 [==============================] - 22s 349ms/step - loss: 0.2890 - accuracy: 0.9102 - val_loss: 1.2983 - val_accuracy: 0.6768
# Epoch 30/40
# 63/63 [==============================] - 16s 258ms/step - loss: 0.3014 - accuracy: 0.9102 - val_loss: 1.5952 - val_accuracy: 0.6162
# Epoch 31/40
# 63/63 [==============================] - 16s 260ms/step - loss: 0.2933 - accuracy: 0.9023 - val_loss: 1.2941 - val_accuracy: 0.6602
# Epoch 32/40
# 63/63 [==============================] - 23s 359ms/step - loss: 0.2623 - accuracy: 0.9170 - val_loss: 1.1893 - val_accuracy: 0.7051
# Epoch 33/40
# 63/63 [==============================] - 16s 259ms/step - loss: 0.2304 - accuracy: 0.9316 - val_loss: 1.7310 - val_accuracy: 0.6006
# Epoch 34/40
# 63/63 [==============================] - 16s 258ms/step - loss: 0.2123 - accuracy: 0.9355 - val_loss: 1.2929 - val_accuracy: 0.6719
# Epoch 35/40
# 63/63 [==============================] - 12s 189ms/step - loss: 0.2452 - accuracy: 0.9180 - val_loss: 1.3240 - val_accuracy: 0.6660
# Epoch 36/40
# 63/63 [==============================] - 19s 303ms/step - loss: 0.1720 - accuracy: 0.9512 - val_loss: 1.1843 - val_accuracy: 0.7100
# Epoch 37/40
# 63/63 [==============================] - 12s 190ms/step - loss: 0.1602 - accuracy: 0.9502 - val_loss: 1.3679 - val_accuracy: 0.6875
# Epoch 38/40
# 63/63 [==============================] - 12s 192ms/step - loss: 0.1858 - accuracy: 0.9404 - val_loss: 1.2395 - val_accuracy: 0.7090
# Epoch 39/40
# 63/63 [==============================] - 16s 259ms/step - loss: 0.1316 - accuracy: 0.9541 - val_loss: 1.4574 - val_accuracy: 0.6611
# Epoch 40/40
# 63/63 [==============================] - 16s 258ms/step - loss: 0.1062 - accuracy: 0.9707 - val_loss: 1.5139 - val_accuracy: 0.6719

# %%
plt.plot(hist["loss"], label="train_loss")
plt.plot(hist["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

plt.plot(hist["accuracy"], label="test_accuracy")
plt.plot(hist["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation accuracies Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
image_batch = []
label_batch = []
image_batch, label_batch = next(iter(test))

t = list(test.as_numpy_iterator())

for i in range(len(test)-1):
    image_batch = np.append(image_batch, t[i+1][0], axis=0)
    label_batch = np.append(label_batch, t[i+1][1], axis=0)


image_batch = image_batch
label_batch = label_batch

predicted_batch = model.predict(image_batch)
predicted_batch = tf.squeeze(predicted_batch).numpy()

predicted_ids = np.argmax(predicted_batch, axis=-1)
# predicted_class_names = class_names[predicted_ids]
# print(predicted_class_names)
# Out:
# 32/32 [==============================] - 13s 267ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Converter as previsões em rótulos de classe
predicted_classes = predicted_ids#np.argmax(probs, axis=1)

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = label_batch#np.argmax(y_test, axis=1)

# Obter os nomes das classes
# class_names = list(validgen.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)
# Out:
# Precisão: 0.6617647058823529

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report

# Calcular a precisão, recall e F1-score para cada classe
report = classification_report(true_classes, predicted_classes, target_names=np.array(metadata.features['label'].names))

# Exibir o relatório de classificação
print(report)
# Out:
#                            precision    recall  f1-score   support
#
#             pink primrose       0.67      0.20      0.31        10
# hard-leaved pocket orchid       1.00      1.00      1.00        10
#          canterbury bells       0.00      0.00      0.00        10
#                 sweet pea       1.00      0.30      0.46        10
#          english marigold       0.70      0.70      0.70        10
#                tiger lily       0.45      0.90      0.60        10
#               moon orchid       1.00      0.20      0.33        10
#          bird of paradise       1.00      0.90      0.95        10
#                 monkshood       0.54      0.70      0.61        10
#             globe thistle       1.00      0.70      0.82        10
#                snapdragon       0.29      0.90      0.44        10
#               colt's foot       0.47      0.70      0.56        10
#               king protea       0.60      0.30      0.40        10
#             spear thistle       0.83      1.00      0.91        10
#               yellow iris       1.00      0.90      0.95        10
#              globe-flower       0.50      0.60      0.55        10
#         purple coneflower       0.91      1.00      0.95        10
#             peruvian lily       0.36      0.90      0.51        10
#            balloon flower       1.00      0.50      0.67        10
#     giant white arum lily       0.62      0.50      0.56        10
#                 fire lily       0.54      0.70      0.61        10
#         pincushion flower       0.78      0.70      0.74        10
#                fritillary       1.00      0.90      0.95        10
#                red ginger       0.64      0.70      0.67        10
#            grape hyacinth       0.91      1.00      0.95        10
#                corn poppy       1.00      0.60      0.75        10
#  prince of wales feathers       0.91      1.00      0.95        10
#          stemless gentian       0.88      0.70      0.78        10
#                 artichoke       0.50      0.90      0.64        10
#             sweet william       0.86      0.60      0.71        10
#                 carnation       0.80      0.80      0.80        10
#              garden phlox       0.00      0.00      0.00        10
#          love in the mist       1.00      0.10      0.18        10
#             mexican aster       1.00      0.40      0.57        10
#          alpine sea holly       1.00      0.50      0.67        10
#      ruby-lipped cattleya       0.60      0.60      0.60        10
#               cape flower       0.77      1.00      0.87        10
#          great masterwort       0.60      0.60      0.60        10
#                siam tulip       0.50      0.50      0.50        10
#               lenten rose       0.64      0.70      0.67        10
#            barbeton daisy       0.50      0.60      0.55        10
#                  daffodil       1.00      0.20      0.33        10
#                sword lily       0.29      0.40      0.33        10
#                poinsettia       1.00      0.60      0.75        10
#          bolero deep blue       0.50      0.30      0.37        10
#                wallflower       0.90      0.90      0.90        10
#                  marigold       1.00      0.80      0.89        10
#                 buttercup       0.58      0.70      0.64        10
#               oxeye daisy       0.80      0.80      0.80        10
#          common dandelion       0.89      0.80      0.84        10
#                   petunia       0.57      0.80      0.67        10
#                wild pansy       0.50      0.80      0.62        10
#                   primula       0.46      0.60      0.52        10
#                 sunflower       1.00      0.80      0.89        10
#               pelargonium       0.83      0.50      0.62        10
#        bishop of llandaff       0.89      0.80      0.84        10
#                     gaura       0.44      0.80      0.57        10
#                  geranium       1.00      0.90      0.95        10
#             orange dahlia       1.00      0.90      0.95        10
#       pink-yellow dahlia?       0.91      1.00      0.95        10
#          cautleya spicata       1.00      0.50      0.67        10
#          japanese anemone       0.60      0.60      0.60        10
#          black-eyed susan       1.00      0.70      0.82        10
#                silverbush       0.88      0.70      0.78        10
#         californian poppy       0.53      0.90      0.67        10
#              osteospermum       1.00      0.90      0.95        10
#             spring crocus       0.90      0.90      0.90        10
#              bearded iris       0.67      0.80      0.73        10
#                windflower       0.64      0.70      0.67        10
#                tree poppy       1.00      0.50      0.67        10
#                   gazania       0.82      0.90      0.86        10
#                    azalea       1.00      0.50      0.67        10
#                water lily       0.53      1.00      0.69        10
#                      rose       0.50      0.70      0.58        10
#               thorn apple       0.69      0.90      0.78        10
#             morning glory       0.60      0.90      0.72        10
#            passion flower       0.36      1.00      0.53        10
#                     lotus       1.00      0.50      0.67        10
#                 toad lily       0.80      0.40      0.53        10
#                 anthurium       0.59      1.00      0.74        10
#                frangipani       0.53      0.90      0.67        10
#                  clematis       0.42      0.80      0.55        10
#                  hibiscus       0.31      0.40      0.35        10
#                 columbine       0.71      0.50      0.59        10
#               desert-rose       0.50      0.30      0.37        10
#               tree mallow       1.00      0.30      0.46        10
#                  magnolia       0.90      0.90      0.90        10
#                  cyclamen       0.57      0.80      0.67        10
#                watercress       0.56      0.50      0.53        10
#                canna lily       0.35      0.70      0.47        10
#               hippeastrum       0.83      0.50      0.62        10
#                  bee balm       0.78      0.70      0.74        10
#                 ball moss       0.73      0.80      0.76        10
#                  foxglove       0.57      0.80      0.67        10
#             bougainvillea       1.00      0.60      0.75        10
#                  camellia       0.80      0.40      0.53        10
#                    mallow       1.00      0.30      0.46        10
#           mexican petunia       1.00      0.20      0.33        10
#                  bromelia       1.00      0.70      0.82        10
#            blanket flower       0.50      0.70      0.58        10
#           trumpet creeper       0.67      0.20      0.31        10
#           blackberry lily       0.86      0.60      0.71        10
#
#                  accuracy                           0.66      1020
#                 macro avg       0.73      0.66      0.65      1020
#              weighted avg       0.73      0.66      0.65      1020
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
