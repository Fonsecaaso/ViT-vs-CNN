# %% [markdown]
# https://www.learndatasci.com/tutorials/hands-on-transfer-learning-keras/

# %%
# import libs and config stuff
## Standard libraries
import os
import numpy as np
import random
import math
import json
from functools import partial
from PIL import Image

## Imports for plotting
import matplotlib.pyplot as plt
plt.set_cmap('cividis')
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgb
import matplotlib
matplotlib.rcParams['lines.linewidth'] = 2.0
import seaborn as sns
sns.reset_orig()

## tqdm for loading bars
from tqdm.notebook import tqdm
from pathlib import Path
import numpy as np

## PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim


## Torchvision
import torchvision
from torchvision import datasets
from torchvision.datasets import CIFAR10
from torchvision import transforms

import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Dense, Dropout, Flatten
from keras import layers


# !pip install -U tensorflow-addons
     

import tensorflow_addons as tfa
# Out:
# <ipython-input-1-3bc222d10891>:15: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg', 'pdf') # For export
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import os 

batch_size = 1
img_size = 75

class_subset = sorted(os.listdir(Path('/content/drive/MyDrive/USP/TCC/experiments/mark 2 (V3)/dataset_flowers_350_images_7_classes/train'))) 

download_dir = Path('/content/drive/MyDrive/USP/TCC/experiments/mark 2 (V3)/dataset_flowers_350_images_7_classes')

train_data_dir = download_dir/'train'
test_data_dir = download_dir/'test'
val_data_dir = download_dir/'val'    

datagen = ImageDataGenerator(rescale=1./255.)

train_generator = datagen.flow_from_directory(
                      train_data_dir,
                      target_size=(img_size, img_size),
                      class_mode='binary',
                      classes=class_subset,
                      subset='training',
                      batch_size=batch_size, 
                      shuffle=True,
                      seed=42
                  )

valid_generator = datagen.flow_from_directory(
                      val_data_dir,
                      target_size=(img_size, img_size),
                      class_mode='binary',
                      classes=class_subset,
                      subset='training',
                      batch_size=batch_size, 
                      shuffle=True,
                      seed=42
                  )

test_generator = datagen.flow_from_directory(
                      test_data_dir,
                      target_size=(img_size, img_size),
                      class_mode='binary',
                      classes=class_subset,
                      subset='training',
                      batch_size=batch_size, 
                      shuffle=True,
                      seed=42
                  )
# Out:
# Found 280 images belonging to 7 classes.
# Found 35 images belonging to 7 classes.
# Found 35 images belonging to 7 classes.

# %%
def create_model():
  inceptionResNetV2_model = tf.keras.applications.InceptionResNetV2(
    include_top=False, 
    weights=None, 
    input_shape=(img_size, img_size,3),
    pooling='avg'
  )
  inceptionResNetV2_model.trainable = True

  input = layers.Input(input_shape)
  x = layers.RandomCrop(img_size, img_size)(input)
  x = layers.RandomFlip("horizontal")(x)
  x = inceptionResNetV2_model(x)
  x = Flatten(name="flatten")(x)
  x = Dense(150, activation='relu')(x)
  x = Dense(150, activation='relu')(x)
  x = Dropout(0.2)(x)
  output = layers.Dense(7, activation="softmax")(x)
  model = keras.Model(inputs=input, outputs=output)
  print(model.summary())
  return model

# %%
input_shape = (img_size, img_size, 3)

# %%
def extract_x_y(gen):
  x = []
  y = []
  x, y = next(gen)
  for i in range(len(gen)-1):
    x = np.append(x, gen[i+1][0], axis=0)
    y = np.append(y, gen[i+1][1], axis=0)
  return x, y

# %%
x_train,y_train = extract_x_y(train_generator)
x_test,y_test = extract_x_y(test_generator)
x_valid,y_valid = extract_x_y(valid_generator)

# %%
print("before reshape: ")
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
print(f"x_valid shape: {x_test.shape} - y_valid shape: {y_test.shape}")

y_test = y_test.reshape((35,1))
y_valid = y_valid.reshape((35,1))
y_train = y_train.reshape((280,1))
y_test = y_test.astype(int)
y_valid = y_valid.astype(int)

print("\n\nafter reshape: ")
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
print(f"x_valid shape: {x_test.shape} - y_valid shape: {y_test.shape}")
# Out:
# before reshape:
# x_train shape: (280, 75, 75, 3) - y_train shape: (280,)
# x_test shape: (35, 75, 75, 3) - y_test shape: (35,)
# x_valid shape: (35, 75, 75, 3) - y_valid shape: (35,)
#
#
# after reshape:
# x_train shape: (280, 75, 75, 3) - y_train shape: (280, 1)
# x_test shape: (35, 75, 75, 3) - y_test shape: (35, 1)
# x_valid shape: (35, 75, 75, 3) - y_valid shape: (35, 1)

# %%
def run_experiment(model):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=.5e-3), 
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=10,
        epochs=80,
        validation_data=(x_test,y_test),
        callbacks=[checkpoint_callback],
    )
    return history


model = create_model()
history = run_experiment(model)
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  random_crop_2 (RandomCrop)  (None, 75, 75, 3)         0
#
#  random_flip_2 (RandomFlip)  (None, 75, 75, 3)         0
#
#  inception_resnet_v2 (Functi  (None, 1536)             54336736
#  onal)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense_6 (Dense)             (None, 150)               230550
#
#  dense_7 (Dense)             (None, 150)               22650
#
#  dropout_2 (Dropout)         (None, 150)               0
#
#  dense_8 (Dense)             (None, 7)                 1057
#
# =================================================================
# Total params: 54,590,993
# Trainable params: 54,530,449
# Non-trainable params: 60,544
# _________________________________________________________________
# None
# Epoch 1/80
# 28/28 [==============================] - 127s 443ms/step - loss: 1.1134 - accuracy: 0.6464 - top-5-accuracy: 0.9643 - val_loss: 2.0512 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 2/80
# 28/28 [==============================] - 4s 128ms/step - loss: 0.7933 - accuracy: 0.7821 - top-5-accuracy: 0.9893 - val_loss: 2.7216 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 3/80
# 28/28 [==============================] - 3s 124ms/step - loss: 0.7771 - accuracy: 0.7464 - top-5-accuracy: 0.9929 - val_loss: 2.3684 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 4/80
# 28/28 [==============================] - 3s 122ms/step - loss: 0.5314 - accuracy: 0.8357 - top-5-accuracy: 0.9893 - val_loss: 3.3532 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 5/80
# 28/28 [==============================] - 3s 122ms/step - loss: 0.4224 - accuracy: 0.8643 - top-5-accuracy: 0.9964 - val_loss: 3.0936 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7714
# Epoch 6/80
# 28/28 [==============================] - 4s 126ms/step - loss: 0.3633 - accuracy: 0.8893 - top-5-accuracy: 1.0000 - val_loss: 5.4234 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.8571
# Epoch 7/80
# 28/28 [==============================] - 3s 123ms/step - loss: 0.3785 - accuracy: 0.8893 - top-5-accuracy: 0.9929 - val_loss: 3.6083 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7429
# Epoch 8/80
# 28/28 [==============================] - 11s 389ms/step - loss: 0.3084 - accuracy: 0.9143 - top-5-accuracy: 1.0000 - val_loss: 2.9143 - val_accuracy: 0.2286 - val_top-5-accuracy: 0.8286
# Epoch 9/80
# 28/28 [==============================] - 7s 253ms/step - loss: 0.3200 - accuracy: 0.9071 - top-5-accuracy: 1.0000 - val_loss: 3.5369 - val_accuracy: 0.2857 - val_top-5-accuracy: 0.7143
# Epoch 10/80
# 28/28 [==============================] - 4s 128ms/step - loss: 0.3988 - accuracy: 0.8786 - top-5-accuracy: 0.9964 - val_loss: 6.1538 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 11/80
# 28/28 [==============================] - 3s 121ms/step - loss: 0.3645 - accuracy: 0.8893 - top-5-accuracy: 1.0000 - val_loss: 3.5643 - val_accuracy: 0.1714 - val_top-5-accuracy: 0.7143
# Epoch 12/80
# 28/28 [==============================] - 3s 120ms/step - loss: 0.3728 - accuracy: 0.9179 - top-5-accuracy: 0.9964 - val_loss: 3.6323 - val_accuracy: 0.2571 - val_top-5-accuracy: 0.8571
# Epoch 13/80
# 28/28 [==============================] - 8s 297ms/step - loss: 0.2885 - accuracy: 0.9143 - top-5-accuracy: 1.0000 - val_loss: 2.0452 - val_accuracy: 0.3714 - val_top-5-accuracy: 0.9429
# Epoch 14/80
# 28/28 [==============================] - 8s 280ms/step - loss: 0.2308 - accuracy: 0.9357 - top-5-accuracy: 1.0000 - val_loss: 1.7475 - val_accuracy: 0.4571 - val_top-5-accuracy: 1.0000
# Epoch 15/80
# 28/28 [==============================] - 7s 267ms/step - loss: 0.2361 - accuracy: 0.9500 - top-5-accuracy: 1.0000 - val_loss: 1.3089 - val_accuracy: 0.5429 - val_top-5-accuracy: 1.0000
# Epoch 16/80
# 28/28 [==============================] - 7s 257ms/step - loss: 0.3491 - accuracy: 0.8964 - top-5-accuracy: 0.9964 - val_loss: 1.7328 - val_accuracy: 0.6286 - val_top-5-accuracy: 1.0000
# Epoch 17/80
# 28/28 [==============================] - 7s 260ms/step - loss: 0.2616 - accuracy: 0.9214 - top-5-accuracy: 0.9964 - val_loss: 0.8563 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch
80
# 28/28 [==============================] - 3s 123ms/step - loss: 0.1786 - accuracy: 0.9500 - top-5-accuracy: 0.9929 - val_loss: 2.4229 - val_accuracy: 0.4857 - val_top-5-accuracy: 1.0000
# Epoch 55/80
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0952 - accuracy: 0.9857 - top-5-accuracy: 0.9964 - val_loss: 0.1113 - val_accuracy: 0.9714 - val_top-5-accuracy: 1.0000
# Epoch 56/80
# 28/28 [==============================] - 4s 131ms/step - loss: 0.0183 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 0.0104 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 57/80
# 28/28 [==============================] - 5s 174ms/step - loss: 0.0494 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 58/80
# 28/28 [==============================] - 5s 176ms/step - loss: 0.1209 - accuracy: 0.9750 - top-5-accuracy: 1.0000 - val_loss: 0.9030 - val_accuracy: 0.8286 - val_top-5-accuracy: 1.0000
# Epoch 59/80
# 28/28 [==============================] - 3s 125ms/step - loss: 0.2496 - accuracy: 0.9429 - top-5-accuracy: 0.9964 - val_loss: 0.3736 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 60/80
# 28/28 [==============================] - 3s 120ms/step - loss: 0.2167 - accuracy: 0.9393 - top-5-accuracy: 0.9929 - val_loss: 0.9419 - val_accuracy: 0.7714 - val_top-5-accuracy: 0.9714
# Epoch 61/80
# 28/28 [==============================] - 3s 125ms/step - loss: 0.1325 - accuracy: 0.9607 - top-5-accuracy: 1.0000 - val_loss: 0.2980 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 62/80
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0613 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.2970 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 63/80
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0329 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0081 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 64/80
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0780 - accuracy: 0.9750 - top-5-accuracy: 1.0000 - val_loss: 0.2455 - val_accuracy: 0.9714 - val_top-5-accuracy: 1.0000
# Epoch 65/80
# 28/28 [==============================] - 4s 128ms/step - loss: 0.1104 - accuracy: 0.9607 - top-5-accuracy: 1.0000 - val_loss: 0.3794 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 66/80
# 28/28 [==============================] - 3s 122ms/step - loss: 0.1245 - accuracy: 0.9679 - top-5-accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 67/80
# 28/28 [==============================] - 3s 120ms/step - loss: 0.0107 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.0079 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 68/80
# 28/28 [==============================] - 3s 124ms/step - loss: 0.0179 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9714 - val_top-5-accuracy: 1.0000
# Epoch 69/80
# 28/28 [==============================] - 4s 129ms/step - loss: 0.0174 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 70/80
# 28/28 [==============================] - 4s 147ms/step - loss: 0.0043 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 5.1930e-04 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 71/80
# 28/28 [==============================] - 3s 121ms/step - loss: 0.0347 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 7.7785e-04 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 72/80
# 28/28 [==============================] - 4s 130ms/step - loss: 0.0100 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 0.0046 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 73/80
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0094 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 74/80
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0026 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 3.0977e-04 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 75/80
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0039 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 76/80
# 28/28 [==============================] - 4s 128ms/step - loss: 0.0016 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.0018 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 77/80
# 28/28 [==============================] - 3s 123ms/step - loss: 0.0068 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 9.4288e-04 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 78/80
# 28/28 [==============================] - 3s 122ms/step - loss: 0.0335 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 7.9308e-04 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 79/80
# 28/28 [==============================] - 4s 127ms/step - loss: 0.0090 - accuracy: 0.9964 - top-5-accuracy: 1.0000 - val_loss: 7.5996e-04 - val_accuracy: 1.0000 - val_top-5-accuracy: 1.0000
# Epoch 80/80
# 28/28 [==============================] - 4s 126ms/step - loss: 0.0306 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.4730 - val_accuracy: 0.9429 - val_top-5-accuracy: 1.0000

# %%
#Some visualizations
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Gerar previsões para o conjunto de dados de validação
predictions = model.predict(x_test)

# Converter as previsões em rótulos de classe
predicted_classes = np.argmax(predictions,axis=1)
predicted_classes = predicted_classes.reshape((35,1))

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = y_test

# Obter os nomes das classes
class_names = list(train_generator.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)

# Criar uma matriz de confusão
confusion_mtx = confusion_matrix(true_classes, predicted_classes)

# Plotar a matriz de confusão usando seaborn
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# 2/2 [==============================] - 5s 660ms/step
# Precisão: 0.9428571428571428

# %%
loss, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4730 - accuracy: 0.9429 - top-5-accuracy: 1.0000
# Test loss: 0.47
# Test accuracy: 94.29%
# Test top 5 accuracy: 100.0%

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Gerar previsões para o conjunto de dados de validação
predictions = model.predict(x_valid)

# Converter as previsões em rótulos de classe
predicted_classes = np.argmax(predictions,axis=1)
predicted_classes = predicted_classes.reshape((35,1))

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = y_valid

# Obter os nomes das classes
class_names = list(train_generator.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)

# Criar uma matriz de confusão
confusion_mtx = confusion_matrix(true_classes, predicted_classes)

# Plotar a matriz de confusão usando seaborn
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# 2/2 [==============================] - 0s 37ms/step
# Precisão: 1.0

# %%
loss, accuracy, top_5_accuracy = model.evaluate(x_valid, y_valid)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0121 - accuracy: 1.0000 - top-5-accuracy: 1.0000
# Test loss: 0.01
# Test accuracy: 100.0%
# Test top 5 accuracy: 100.0%
