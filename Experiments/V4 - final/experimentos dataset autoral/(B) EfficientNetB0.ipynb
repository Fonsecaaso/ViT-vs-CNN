# %% [markdown]
# https://www.learndatasci.com/tutorials/hands-on-transfer-learning-keras/

# %%
# import libs and config stuff
## Standard libraries
import os
import numpy as np
import random
import math
import json
from functools import partial
from PIL import Image

## Imports for plotting
import matplotlib.pyplot as plt
plt.set_cmap('cividis')
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgb
import matplotlib
matplotlib.rcParams['lines.linewidth'] = 2.0
import seaborn as sns
sns.reset_orig()

## tqdm for loading bars
from tqdm.notebook import tqdm
from pathlib import Path
import numpy as np

## PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim


## Torchvision
import torchvision
from torchvision import datasets
from torchvision.datasets import CIFAR10
from torchvision import transforms

import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Model, Sequential
from keras.optimizers import Adam

# !pip install efficientnet==1.1.0
from efficientnet import tfkeras as efficientnet
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Dense, Dropout, Flatten
from keras import layers


# !pip install -U tensorflow-addons
     

import tensorflow_addons as tfa
# Out:
# <ipython-input-1-29d453d33f01>:15: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg', 'pdf') # For export
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting efficientnet==1.1.0
#   Downloading efficientnet-1.1.0-py3-none-any.whl (18 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet==1.1.0)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet==1.1.0) (0.19.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (1.22.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.1.0) (3.8.0)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.0) (1.10.1)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.0) (3.1)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.0) (8.4.0)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.0) (2.25.1)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.0) (2023.4.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.0) (1.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet==1.1.0) (23.1)
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.0 keras-applications-1.0.8
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (23.1)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
# Successfully installed tensorflow-addons-0.20.0 typeguard-2.13.3
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import os 

batch_size = 1
img_size = 75

class_subset = sorted(os.listdir(Path('/content/drive/MyDrive/USP/TCC/experiments/mark 2 (V3)/dataset_flowers_350_images_7_classes/train'))) 

download_dir = Path('/content/drive/MyDrive/USP/TCC/experiments/mark 2 (V3)/dataset_flowers_350_images_7_classes')

train_data_dir = download_dir/'train'
test_data_dir = download_dir/'test'
val_data_dir = download_dir/'val'    

datagen = ImageDataGenerator(rescale=1./255.)

train_generator = datagen.flow_from_directory(
                      train_data_dir,
                      target_size=(img_size, img_size),
                      class_mode='binary',
                      classes=class_subset,
                      subset='training',
                      batch_size=batch_size, 
                      shuffle=True,
                      seed=42
                  )

valid_generator = datagen.flow_from_directory(
                      val_data_dir,
                      target_size=(img_size, img_size),
                      class_mode='binary',
                      classes=class_subset,
                      subset='training',
                      batch_size=batch_size, 
                      shuffle=True,
                      seed=42
                  )

test_generator = datagen.flow_from_directory(
                      test_data_dir,
                      target_size=(img_size, img_size),
                      class_mode='binary',
                      classes=class_subset,
                      subset='training',
                      batch_size=batch_size, 
                      shuffle=True,
                      seed=42
                  )
# Out:
# Found 280 images belonging to 7 classes.
# Found 35 images belonging to 7 classes.
# Found 35 images belonging to 7 classes.

# %%
def create_model():

  efficientnet_model = efficientnet.EfficientNetB0(
      weights=None,
      pooling='avg',
      include_top=False,
      input_shape=(img_size,img_size,3)
  )

  input = layers.Input(input_shape)
  x = layers.RandomCrop(img_size, img_size)(input)
  x = layers.RandomFlip("horizontal")(x)
  x = efficientnet_model(x)
  x = Flatten(name="flatten")(x)
  x = Dense(150, activation='relu')(x)
  x = Dense(150, activation='relu')(x)
  x = Dropout(0.2)(x)
  output = layers.Dense(7, activation="softmax")(x)
  model = keras.Model(inputs=input, outputs=output)
  print(model.summary())
  return model

# %%
input_shape = (img_size, img_size, 3)
n_classes=7

# %%
def extract_x_y(gen):
  x = []
  y = []
  x, y = next(gen)
  for i in range(len(gen)-1):
    x = np.append(x, gen[i+1][0], axis=0)
    y = np.append(y, gen[i+1][1], axis=0)
  return x, y

# %%
x_train,y_train = extract_x_y(train_generator)
x_test,y_test = extract_x_y(test_generator)
x_valid,y_valid = extract_x_y(valid_generator)

# %%
print("before reshape: ")
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
print(f"x_valid shape: {x_test.shape} - y_valid shape: {y_test.shape}")

y_test = y_test.reshape((35,1))
y_valid = y_valid.reshape((35,1))
y_train = y_train.reshape((280,1))
y_test = y_test.astype(int)
y_valid = y_valid.astype(int)

print("\n\nafter reshape: ")
print(f"x_train shape: {x_train.shape} - y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape} - y_test shape: {y_test.shape}")
print(f"x_valid shape: {x_test.shape} - y_valid shape: {y_test.shape}")
# Out:
# before reshape:
# x_train shape: (280, 75, 75, 3) - y_train shape: (280,)
# x_test shape: (35, 75, 75, 3) - y_test shape: (35,)
# x_valid shape: (35, 75, 75, 3) - y_valid shape: (35,)
#
#
# after reshape:
# x_train shape: (280, 75, 75, 3) - y_train shape: (280, 1)
# x_test shape: (35, 75, 75, 3) - y_test shape: (35, 1)
# x_valid shape: (35, 75, 75, 3) - y_valid shape: (35, 1)

# %%
def run_experiment(model):
    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3), 
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )

    history = model.fit(
        x=x_train,
        y=y_train,
        batch_size=10,
        epochs=80,
        validation_data=(x_test,y_test),
        callbacks=[checkpoint_callback],
    )

    model.load_weights(checkpoint_filepath)

    return history


model = create_model()
history = run_experiment(model)
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 75, 75, 3)]       0
#
#  random_crop_1 (RandomCrop)  (None, 75, 75, 3)         0
#
#  random_flip_1 (RandomFlip)  (None, 75, 75, 3)         0
#
#  efficientnet-b0 (Functional  (None, 1280)             4049564
#  )
#
#  flatten (Flatten)           (None, 1280)              0
#
#  dense_3 (Dense)             (None, 150)               192150
#
#  dense_4 (Dense)             (None, 150)               22650
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_5 (Dense)             (None, 7)                 1057
#
# =================================================================
# Total params: 4,265,421
# Trainable params: 4,223,405
# Non-trainable params: 42,016
# _________________________________________________________________
# None
# Epoch 1/80
# 28/28 [==============================] - 57s 174ms/step - loss: 1.9850 - accuracy: 0.2000 - top-5-accuracy: 0.7893 - val_loss: 1.9510 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 2/80
# 28/28 [==============================] - 1s 41ms/step - loss: 1.7230 - accuracy: 0.3143 - top-5-accuracy: 0.9036 - val_loss: 1.9995 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 3/80
# 28/28 [==============================] - 1s 41ms/step - loss: 1.5695 - accuracy: 0.3786 - top-5-accuracy: 0.9357 - val_loss: 2.0821 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 4/80
# 28/28 [==============================] - 1s 40ms/step - loss: 1.6027 - accuracy: 0.3821 - top-5-accuracy: 0.9321 - val_loss: 2.0330 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 5/80
# 28/28 [==============================] - 1s 45ms/step - loss: 1.5579 - accuracy: 0.4179 - top-5-accuracy: 0.9536 - val_loss: 2.5455 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 6/80
# 28/28 [==============================] - 1s 48ms/step - loss: 1.3205 - accuracy: 0.4929 - top-5-accuracy: 0.9607 - val_loss: 4.2046 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 7/80
# 28/28 [==============================] - 1s 45ms/step - loss: 1.3126 - accuracy: 0.4786 - top-5-accuracy: 0.9643 - val_loss: 6.7386 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 8/80
# 28/28 [==============================] - 1s 43ms/step - loss: 1.2808 - accuracy: 0.5250 - top-5-accuracy: 0.9750 - val_loss: 5.6867 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 9/80
# 28/28 [==============================] - 1s 39ms/step - loss: 1.0416 - accuracy: 0.5536 - top-5-accuracy: 0.9714 - val_loss: 6.9242 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7143
# Epoch 10/80
# 28/28 [==============================] - 2s 68ms/step - loss: 0.9733 - accuracy: 0.5786 - top-5-accuracy: 0.9929 - val_loss: 5.5242 - val_accuracy: 0.1714 - val_top-5-accuracy: 0.7429
# Epoch 11/80
# 28/28 [==============================] - 1s 38ms/step - loss: 1.1581 - accuracy: 0.5964 - top-5-accuracy: 0.9714 - val_loss: 6.8040 - val_accuracy: 0.1429 - val_top-5-accuracy: 0.7429
# Epoch 12/80
# 28/28 [==============================] - 2s 68ms/step - loss: 1.0012 - accuracy: 0.6107 - top-5-accuracy: 0.9893 - val_loss: 6.7638 - val_accuracy: 0.2286 - val_top-5-accuracy: 0.8571
# Epoch 13/80
# 28/28 [==============================] - 1s 39ms/step - loss: 1.1096 - accuracy: 0.6357 - top-5-accuracy: 0.9786 - val_loss: 5.7932 - val_accuracy: 0.1714 - val_top-5-accuracy: 0.8857
# Epoch 14/80
# 28/28 [==============================] - 1s 42ms/step - loss: 0.8556 - accuracy: 0.6929 - top-5-accuracy: 0.9857 - val_loss: 5.7555 - val_accuracy: 0.2000 - val_top-5-accuracy: 0.8286
# Epoch 15/80
# 28/28 [==============================] - 2s 68ms/step - loss: 0.7987 - accuracy: 0.7000 - top-5-accuracy: 0.9893 - val_loss: 3.7347 - val_accuracy: 0.3714 - val_top-5-accuracy: 0.9143
# Epoch 16/80
# 28/28 [==============================] - 1s 45ms/step - loss: 0.7982 - accuracy: 0.7250 - top-5-accuracy: 0.9893 - val_loss: 3.3351 - val_accuracy: 0.3714 - val_top-5-accuracy: 1.0000
# Epoch 17/80
# 28/28 [==============================] - 2s 88ms/step - loss: 0.5879 - accuracy: 0.7893 - top-5-accuracy: 0.9964 - val_loss: 1.6750 - val_accuracy: 0.5143 - val_top-5-accuracy: 1.0000
# Epoch 18/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.5836 - accuracy: 0.7929 - top-5-accuracy: 0.9929 - val_loss: 3.5994 - val_accuracy: 0.3143 - val_top-5-accuracy: 0.8286
# Epoch 19/80
# 28/28 [==============================] - 1s 42ms/step - loss: 0.8114 - accuracy: 0.7321 - top-5-accuracy: 0.9929 - val_loss: 2.9680 - val_accuracy: 0.4571 - val_top-5-accuracy: 1.0000
# Epoch 20/80
# 28/28 [==============================] - 2s 70ms/step - loss: 0.8594 - accuracy: 0.7214 - top-5-accuracy: 0.9929 - val_loss: 1.2211 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch 21/80
# 28/28 [==============================] - 2s 69ms/step - loss: 0.6838 - accuracy: 0.8036 - top-5-accuracy: 0.9857 - val_loss: 0.8302 - val_accuracy: 0.8286 - val_top-5-accuracy: 0.9714
# Epoch 22/80
# 28/28 [==============================] - 1s 41ms/step - loss: 0.5565 - accuracy: 0.8286 - top-5-accuracy: 0.9964 - val_loss: 0.4711 - val_accuracy: 0.8286 - val_top-5-accuracy: 1.0000
# Epoch 23/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.4902 - accuracy: 0.8464 - top-5-accuracy: 0.9964 - val_loss: 1.5013 - val_accuracy: 0.7714 - val_top-5-accuracy: 1.0000
# Epoch 24/80
# 28/28 [==============================] - 2s 75ms/step - loss: 0.5049 - accuracy: 0.8679 - top-5-accuracy: 0.9857 - val_loss: 0.4652 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 25/80
# 28/28 [==============================] - 1s 43ms/step - loss: 0.4999 - accuracy: 0.8393 - top-5-accuracy: 0.9893 - val_loss: 0.4712 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 26/80
# 28/28 [==============================] - 2s 71ms/step - loss: 0.3927 - accuracy: 0.8500 - top-5-accuracy: 1.0000 - val_loss: 0.2756 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 27/80
# 28/28 [==============================] - 1s 41ms/step - loss: 0.2747 - accuracy: 0.9036 - top-5-accuracy: 1.0000 - val_loss: 0.4070 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 28/80
# 28/28 [==============================] - 1s 41ms/step - loss: 0
- val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 56/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1391 - accuracy: 0.9571 - top-5-accuracy: 1.0000 - val_loss: 0.1249 - val_accuracy: 0.9429 - val_top-5-accuracy: 1.0000
# Epoch 57/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1859 - accuracy: 0.9500 - top-5-accuracy: 0.9929 - val_loss: 0.2145 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 58/80
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1792 - accuracy: 0.9393 - top-5-accuracy: 0.9964 - val_loss: 0.3344 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 59/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2378 - accuracy: 0.9429 - top-5-accuracy: 1.0000 - val_loss: 0.2785 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 60/80
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2025 - accuracy: 0.9607 - top-5-accuracy: 0.9964 - val_loss: 0.3243 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 61/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1345 - accuracy: 0.9750 - top-5-accuracy: 0.9964 - val_loss: 0.2258 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 62/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1657 - accuracy: 0.9607 - top-5-accuracy: 1.0000 - val_loss: 0.7595 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch 63/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2305 - accuracy: 0.9357 - top-5-accuracy: 0.9929 - val_loss: 0.5417 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 64/80
# 28/28 [==============================] - 1s 42ms/step - loss: 0.1028 - accuracy: 0.9714 - top-5-accuracy: 1.0000 - val_loss: 0.4653 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch 65/80
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0677 - accuracy: 0.9750 - top-5-accuracy: 1.0000 - val_loss: 0.3350 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 66/80
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0953 - accuracy: 0.9786 - top-5-accuracy: 0.9964 - val_loss: 0.3717 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 67/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1233 - accuracy: 0.9714 - top-5-accuracy: 1.0000 - val_loss: 0.5034 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 68/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.2204 - accuracy: 0.9464 - top-5-accuracy: 1.0000 - val_loss: 1.1190 - val_accuracy: 0.7429 - val_top-5-accuracy: 1.0000
# Epoch 69/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1599 - accuracy: 0.9571 - top-5-accuracy: 1.0000 - val_loss: 0.5164 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 70/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0670 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.6692 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch 71/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.1178 - accuracy: 0.9607 - top-5-accuracy: 0.9964 - val_loss: 0.1245 - val_accuracy: 0.9429 - val_top-5-accuracy: 1.0000
# Epoch 72/80
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1688 - accuracy: 0.9500 - top-5-accuracy: 1.0000 - val_loss: 0.3201 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 73/80
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0686 - accuracy: 0.9714 - top-5-accuracy: 1.0000 - val_loss: 0.3808 - val_accuracy: 0.8571 - val_top-5-accuracy: 1.0000
# Epoch 74/80
# 28/28 [==============================] - 1s 40ms/step - loss: 0.0424 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.8402 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch 75/80
# 28/28 [==============================] - 1s 39ms/step - loss: 0.0523 - accuracy: 0.9821 - top-5-accuracy: 1.0000 - val_loss: 0.3780 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 76/80
# 28/28 [==============================] - 1s 44ms/step - loss: 0.0540 - accuracy: 0.9857 - top-5-accuracy: 1.0000 - val_loss: 0.4977 - val_accuracy: 0.8857 - val_top-5-accuracy: 1.0000
# Epoch 77/80
# 28/28 [==============================] - 1s 42ms/step - loss: 0.0166 - accuracy: 0.9929 - top-5-accuracy: 1.0000 - val_loss: 0.3652 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 78/80
# 28/28 [==============================] - 1s 41ms/step - loss: 0.1218 - accuracy: 0.9786 - top-5-accuracy: 1.0000 - val_loss: 0.2390 - val_accuracy: 0.9143 - val_top-5-accuracy: 1.0000
# Epoch 79/80
# 28/28 [==============================] - 1s 39ms/step - loss: 0.2178 - accuracy: 0.9464 - top-5-accuracy: 1.0000 - val_loss: 1.3919 - val_accuracy: 0.8000 - val_top-5-accuracy: 1.0000
# Epoch 80/80
# 28/28 [==============================] - 1s 39ms/step - loss: 0.1091 - accuracy: 0.9750 - top-5-accuracy: 1.0000 - val_loss: 0.9353 - val_accuracy: 0.7714 - val_top-5-accuracy: 0.9714

# %%
#Some visualizations
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Gerar previsões para o conjunto de dados de validação
predictions = model.predict(x_test)

# Converter as previsões em rótulos de classe
predicted_classes = np.argmax(predictions,axis=1)
predicted_classes = predicted_classes.reshape((35,1))

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = y_test

# Obter os nomes das classes
class_names = list(train_generator.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)

# Criar uma matriz de confusão
confusion_mtx = confusion_matrix(true_classes, predicted_classes)

# Plotar a matriz de confusão usando seaborn
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# 2/2 [==============================] - 2s 459ms/step
# Precisão: 1.0

# %%
loss, accuracy, top_5_accuracy = model.evaluate(x_test, y_test)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# 2/2 [==============================] - 0s 15ms/step - loss: 0.0732 - accuracy: 1.0000 - top-5-accuracy: 1.0000
# Test loss: 0.07
# Test accuracy: 100.0%
# Test top 5 accuracy: 100.0%

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Gerar previsões para o conjunto de dados de validação
predictions = model.predict(x_valid)

# Converter as previsões em rótulos de classe
predicted_classes = np.argmax(predictions,axis=1)
predicted_classes = predicted_classes.reshape((35,1))

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = y_valid

# Obter os nomes das classes
class_names = list(train_generator.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)

# Criar uma matriz de confusão
confusion_mtx = confusion_matrix(true_classes, predicted_classes)

# Plotar a matriz de confusão usando seaborn
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# 2/2 [==============================] - 0s 13ms/step
# Precisão: 0.8857142857142857

# %%
loss, accuracy, top_5_accuracy = model.evaluate(x_valid, y_valid)
print(f"Test loss: {round(loss, 2)}")
print(f"Test accuracy: {round(accuracy * 100, 2)}%")
print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")
# Out:
# 2/2 [==============================] - 0s 16ms/step - loss: 0.4827 - accuracy: 0.8857 - top-5-accuracy: 1.0000
# Test loss: 0.48
# Test accuracy: 88.57%
# Test top 5 accuracy: 100.0%
