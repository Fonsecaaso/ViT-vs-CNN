# %%
# import libs and config stuff
## Standard libraries
import os
import numpy as np
import random
import math
import json
from functools import partial
from PIL import Image

## Imports for plotting
import matplotlib.pyplot as plt
plt.set_cmap('cividis')
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('svg', 'pdf') # For export
from matplotlib.colors import to_rgb
import matplotlib
matplotlib.rcParams['lines.linewidth'] = 2.0
import seaborn as sns
sns.reset_orig()

## tqdm for loading bars
from tqdm.notebook import tqdm
from pathlib import Path
import numpy as np

## PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
import torch.optim as optim


## Torchvision
import torchvision
from torchvision import datasets
from torchvision.datasets import CIFAR10
from torchvision import transforms

import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.models import Model
from keras.optimizers import Adam
from keras.applications.convnext import ConvNeXtXLarge, preprocess_input
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Dense, Dropout, Flatten
from keras import layers
# Out:
# <ipython-input-1-d1b3169775ab>:15: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   set_matplotlib_formats('svg', 'pdf') # For export

# %%
BATCH_SIZE = 1
img_size = 72

from keras.preprocessing.image import ImageDataGenerator
from pathlib import Path


download_dir = Path('/content/drive/MyDrive/USP/TCC/experiments/dataset_flowers_350_images_7_classes')

class_subset = sorted(os.listdir(Path('/content/drive/MyDrive/USP/TCC/experiments/dataset_flowers_350_images_7_classes/train')))

# %%
train_data_dir = download_dir/'train'
test_data_dir = download_dir/'test'
val_data_dir = download_dir/'val'

datagen = ImageDataGenerator(rescale=1./255.)

traingen = datagen.flow_from_directory(train_data_dir,
                                               target_size=(img_size, img_size),
                                               class_mode='categorical',
                                               classes=class_subset,
                                              #  subset='training',
                                               batch_size=BATCH_SIZE, 
                                               shuffle=True,
                                               seed=42)

validgen = datagen.flow_from_directory(val_data_dir,
                                               target_size=(img_size, img_size),
                                               class_mode='categorical',
                                               classes=class_subset,
                                              #  subset='validation',
                                               batch_size=BATCH_SIZE,
                                               shuffle=True,
                                               seed=42)

testgen = datagen.flow_from_directory(test_data_dir,
                                             target_size=(img_size, img_size),
                                             class_mode='categorical',
                                             classes=class_subset,
                                             batch_size=1,
                                             shuffle=True,
                                             seed=42)
# Out:
# Found 280 images belonging to 7 classes.
# Found 35 images belonging to 7 classes.
# Found 35 images belonging to 7 classes.

# %%
def create_model(input_shape, n_classes, optimizer='rmsprop', fine_tune=0):
    conv_base = ConvNeXtXLarge(include_top=False, weights='imagenet', input_shape=input_shape)

    if fine_tune > 0:
        for layer in conv_base.layers[:-fine_tune]:
            layer.trainable = False
    else:
        for layer in conv_base.layers:
            layer.trainable = False

    # Create a new 'top' of the model (i.e. fully-connected layers).
    # This is 'bootstrapping' a new top_model onto the pretrained layers.
    top_model = conv_base.output
    top_model = Flatten(name="flatten")(top_model)
    top_model = Dense(4096, activation='relu')(top_model)
    top_model = Dense(1072, activation='relu')(top_model)
    top_model = Dropout(0.2)(top_model)
    output_layer = Dense(n_classes, activation='softmax')(top_model)
    
    # Group the convolutional base and new fully-connected layers into a Model object.
    model = Model(inputs=conv_base.input, outputs=output_layer)

    model.compile(
        optimizer=optimizer,
        loss=keras.losses.BinaryCrossentropy(from_logits=True),
        metrics=[
            keras.metrics.BinaryAccuracy(name="accuracy")
        ],
    )
    
    return model

# %%
input_shape = (72, 72, 3)
optim_1 = Adam(learning_rate=0.001)
n_classes=7

n_steps = traingen.samples // BATCH_SIZE
n_val_steps = validgen.samples // BATCH_SIZE
n_epochs = 30

# First we'll train the model without Fine-tuning
model = create_model(input_shape, n_classes, optim_1, fine_tune=0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_xlarge_notop.h5
# 1393257616/1393257616 [==============================] - 7s 0us/step

# %%
def run_experiment(model):
    checkpoint_filepath = "/tmp/checkpoint"
    checkpoint_callback = keras.callbacks.ModelCheckpoint(
        checkpoint_filepath,
        monitor="val_accuracy",
        save_best_only=True,
        save_weights_only=True,
    )
    history = model.fit(traingen,
                            batch_size=BATCH_SIZE,
                            epochs=30,#n_epochs,
                            validation_data=validgen,
                            steps_per_epoch=n_steps,
                            validation_steps=n_val_steps,
                            callbacks=[checkpoint_callback])
    return history

history = run_experiment(model)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/backend.py:5703: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 280/280 [==============================] - 189s 579ms/step - loss: 0.5977 - accuracy: 0.8959 - val_loss: 0.2727 - val_accuracy: 0.9347
# Epoch 2/30
# 280/280 [==============================] - 78s 277ms/step - loss: 0.0835 - accuracy: 0.9781 - val_loss: 0.1762 - val_accuracy: 0.9551
# Epoch 3/30
# 280/280 [==============================] - 73s 259ms/step - loss: 0.0763 - accuracy: 0.9847 - val_loss: 0.0616 - val_accuracy: 0.9837
# Epoch 4/30
# 280/280 [==============================] - 66s 237ms/step - loss: 0.0504 - accuracy: 0.9878 - val_loss: 0.0640 - val_accuracy: 0.9673
# Epoch 5/30
# 280/280 [==============================] - 62s 222ms/step - loss: 0.0209 - accuracy: 0.9923 - val_loss: 0.0358 - val_accuracy: 0.9837
# Epoch 6/30
# 280/280 [==============================] - 65s 234ms/step - loss: 0.1771 - accuracy: 0.9781 - val_loss: 0.1777 - val_accuracy: 0.9592
# Epoch 7/30
# 280/280 [==============================] - 63s 224ms/step - loss: 0.1915 - accuracy: 0.9776 - val_loss: 0.2417 - val_accuracy: 0.9510
# Epoch 8/30
# 280/280 [==============================] - 73s 259ms/step - loss: 0.0331 - accuracy: 0.9944 - val_loss: 0.0403 - val_accuracy: 0.9918
# Epoch 9/30
# 280/280 [==============================] - 63s 226ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.0987 - val_accuracy: 0.9673
# Epoch 10/30
# 280/280 [==============================] - 65s 231ms/step - loss: 0.0102 - accuracy: 0.9974 - val_loss: 0.0371 - val_accuracy: 0.9918
# Epoch 11/30
# 280/280 [==============================] - 72s 258ms/step - loss: 6.8894e-04 - accuracy: 1.0000 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 12/30
# 280/280 [==============================] - 63s 224ms/step - loss: 2.0041e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 13/30
# 280/280 [==============================] - 64s 228ms/step - loss: 2.3072e-05 - accuracy: 1.0000 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 14/30
# 280/280 [==============================] - 62s 221ms/step - loss: 1.6474e-05 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 15/30
# 280/280 [==============================] - 63s 226ms/step - loss: 7.3064e-06 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 16/30
# 280/280 [==============================] - 66s 237ms/step - loss: 8.0066e-06 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 17/30
# 280/280 [==============================] - 62s 220ms/step - loss: 6.4580e-06 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 18/30
# 280/280 [==============================] - 63s 224ms/step - loss: 4.4604e-06 - accuracy: 1.0000 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 19/30
# 280/280 [==============================] - 61s 217ms/step - loss: 5.9043e-06 - accuracy: 1.0000 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 20/30
# 280/280 [==============================] - 63s 224ms/step - loss: 1.0497e-05 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 21/30
# 280/280 [==============================] - 62s 222ms/step - loss: 9.2927e-06 - accuracy: 1.0000 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 22/30
# 280/280 [==============================] - 64s 227ms/step - loss: 2.8071e-06 - accuracy: 1.0000 - val_loss: 0.0034 - val_accuracy: 1.0000
# Epoch 23/30
# 280/280 [==============================] - 66s 236ms/step - loss: 2.8669e-06 - accuracy: 1.0000 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 24/30
# 280/280 [==============================] - 61s 219ms/step - loss: 2.7673e-06 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 25/30
# 280/280 [==============================] - 63s 224ms/step - loss: 3.4329e-06 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 26/30
# 280/280 [==============================] - 62s 220ms/step - loss: 3.9284e-06 - accuracy: 1.0000 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 27/30
# 280/280 [==============================] - 63s 225ms/step - loss: 1.1046e-06 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 28/30
# 280/280 [==============================] - 62s 220ms/step - loss: 8.8284e-07 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 29/30
# 280/280 [==============================] - 63s 226ms/step - loss: 8.9824e-07 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 30/30
# 280/280 [==============================] - 63s 225ms/step - loss: 1.2699e-06 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000

# %%
#Some visualizations
import matplotlib.pyplot as plt
#Loss
plt.plot(history.history['loss'],label='loss')
plt.plot(history.history['val_loss'],label='val_loss')
plt.legend()
plt.show()
#Accuracy
plt.plot(history.history['accuracy'],label='acc')
plt.plot(history.history['val_accuracy'],label='val_acc')
plt.legend()
plt.show()

# %%
# x_train = []
# y_train = []
# x_train,y_train = next(train_generator)
x_test = []
y_test = []
x_test,y_test = next(validgen)

# for i in range(len(train_generator)-1):
#     x_train = np.append(x_train, train_generator[i+1][0], axis=0)
#     y_train = np.append(y_train, train_generator[i+1][1], axis=0)
for i in range(len(validgen)-1):
    x_test = np.append(x_test, validgen[i+1][0], axis=0)
    y_test = np.append(y_test, validgen[i+1][1], axis=0)

# %%
probs = model.predict(x_test)
# Out:
# 2/2 [==============================] - 11s 3s/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Converter as previsões em rótulos de classe
predicted_classes = np.argmax(probs, axis=1)

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = np.argmax(y_test, axis=1)

# Obter os nomes das classes
class_names = list(validgen.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)

# Criar uma matriz de confusão
confusion_mtx = confusion_matrix(true_classes, predicted_classes)

# Plotar a matriz de confusão usando seaborn
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# Precisão: 1.0

# %%
x_test = []
y_test = []
x_test,y_test = next(testgen)

for i in range(len(testgen)-1):
    x_test = np.append(x_test, testgen[i+1][0], axis=0)
    y_test = np.append(y_test, testgen[i+1][1], axis=0)

# %%
probs = model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 61ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Converter as previsões em rótulos de classe
predicted_classes = np.argmax(probs, axis=1)

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = np.argmax(y_test, axis=1)

# Obter os nomes das classes
class_names = list(testgen.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)

# Criar uma matriz de confusão
confusion_mtx = confusion_matrix(true_classes, predicted_classes)

# Plotar a matriz de confusão usando seaborn
sns.set()
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='YlGnBu', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Previsão')
plt.ylabel('Real')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# Precisão: 0.9428571428571428

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 72, 72, 3)]  0           []
#
#  convnext_xlarge_prestem_normal  (None, 72, 72, 3)   0           ['input_1[0][0]']
#  ization (Normalization)
#
#  convnext_xlarge_stem (Sequenti  (None, None, None,   13056      ['convnext_xlarge_prestem_normali
#  al)                            256)                             zation[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  12800      ['convnext_xlarge_stem[0][0]']
#  0_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  512        ['convnext_xlarge_stage_0_block_0
#  0_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 1024  263168     ['convnext_xlarge_stage_0_block_0
#  0_pointwise_conv_1 (Dense)     )                                _layernorm[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 1024  0          ['convnext_xlarge_stage_0_block_0
#  0_gelu (Activation)            )                                _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  262400     ['convnext_xlarge_stage_0_block_0
#  0_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  256        ['convnext_xlarge_stage_0_block_0
#  0_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  0          ['convnext_xlarge_stage_0_block_0
#  0_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 18, 18, 256)  0          ['convnext_xlarge_stem[0][0]',
#  da)                                                              'convnext_xlarge_stage_0_block_0
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  12800      ['tf.__operators__.add[0][0]']
#  1_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  512        ['convnext_xlarge_stage_0_block_1
#  1_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 1024  263168     ['convnext_xlarge_stage_0_block_1
#  1_pointwise_conv_1 (Dense)     )                                _layernorm[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 1024  0          ['convnext_xlarge_stage_0_block_1
#  1_gelu (Activation)            )                                _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  262400     ['convnext_xlarge_stage_0_block_1
#  1_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  256        ['convnext_xlarge_stage_0_block_1
#  1_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  0          ['convnext_xlarge_stage_0_block_1
#  1_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 18, 18, 256)  0          ['tf.__operators__.add[0][0]',
#  mbda)                                                            'convnext_xlarge_stage_0_block_1
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  12800      ['tf.__operators__.add_1[0][0]']
#  2_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  512        ['convnext_xlarge_stage_0_block_2
#  2_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 1024  263168     ['convnext_xlarge_stage_0_block_2
#  2_pointwise_conv_1 (Dense)     )                                _layernorm[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 1024  0          ['convnext_xlarge_stage_0_block_2
#  2_gelu (Activation)            )                                _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  262400     ['convnext_xlarge_stage_0_block_2
#  2_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  256        ['convnext_xlarge_stage_0_block_2
#  2_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 18, 18, 256)  0          ['convnext_xlarge_stage_0_block_2
#  2_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 18, 18, 256)  0          ['tf.__operators__.add_1[0][0]',
#  mbda)                                                            'convnext_xlarge_stage_0_block_2
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_downsampling_b  (None, None, None,   525312     ['tf.__operators__.add_2[0][0]']
#  lock_0 (Sequential)            512)
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   25600       ['convnext_xlarge_downsampling_bl
#  0_depthwise_conv (Conv2D)                                       ock_0[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   1024        ['convnext_xlarge_stage_1_block_0
#  0_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 2048)  1050624     ['convnext_xlarge_stage_1_block_0
#  0_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 2048)  0           ['convnext_xlarge_stage_1_block_0
#  0_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   1049088     ['convnext_xlarge_stage_1_block_0
#  0_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   512         ['convnext_xlarge_stage_1_block_0
#  0_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   0           ['convnext_xlarge_stage_1_block_0
#  0_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 9, 9, 512)   0           ['convnext_xlarge_downsampling_bl
#  mbda)                                                           ock_0[0][0]',
#                                                                   'convnext_xlarge_stage_1_block_0
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   25600       ['tf.__operators__.add_3[0][0]']
#  1_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   1024        ['convnext_xlarge_stage_1_block_1
#  1_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 2048)  1050624     ['convnext_xlarge_stage_1_block_1
#  1_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 2048)  0           ['convnext_xlarge_stage_1_block_1
#  1_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   1049088     ['convnext_xlarge_stage_1_block_1
#  1_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   512         ['convnext_xlarge_stage_1_block_1
#  1_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   0           ['convnext_xlarge_stage_1_block_1
#  1_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 9, 9, 512)   0           ['tf.__operators__.add_3[0][0]',
#  mbda)                                                            'convnext_xlarge_stage_1_block_1
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   25600       ['tf.__operators__.add_4[0][0]']
#  2_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   1024        ['convnext_xlarge_stage_1_block_2
#  2_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 2048)  1050624     ['convnext_xlarge_stage_1_block_2
#  2_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 2048)  0           ['convnext_xlarge_stage_1_block_2
#  2_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   1049088     ['convnext_xlarge_stage_1_block_2
#  2_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   512         ['convnext_xlarge_stage_1_block_2
#  2_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 9, 9, 512)   0           ['convnext_xlarge_stage_1_block_2
#  2_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 9, 9, 512)   0           ['tf.__operators__.add_4[0][0]',
#  mbda)                                                            'convnext_xlarge_stage_1_block_2
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_downsampling_b  (None, None, None,   2099200    ['tf.__operators__.add_5[0][0]']
#  lock_1 (Sequential)            1024)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['convnext_xlarge_downsampling_bl
#  0_depthwise_conv (Conv2D)                                       ock_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_0
#  0_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_0
#  0_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_0
#  0_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_0
#  0_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_0
#  0_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_0
#  0_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 4, 4, 1024)  0           ['convnext_xlarge_downsampling_bl
#  mbda)                                                           ock_1[0][0]',
#                                                                   'convnext_xlarge_stage_2_block_0
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_6[0][0]']
#  1_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_1
#  1_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_1
#  1_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_1
#  1_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_1
#  1_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_1
#  1_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_1
#  1_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 4, 4, 1024)  0           ['tf.__operators__.add_6[0][0]',
#  mbda)                                                            'convnext_xlarge_stage_2_block_1
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_7[0][0]']
#  2_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_2
#  2_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_2
#  2_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_2
#  2_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_2
#  2_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_2
#  2_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_2
#  2_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_8 (TFOpLa  (None, 4, 4, 1024)  0           ['tf.__operators__.add_7[0][0]',
#  mbda)                                                            'convnext_xlarge_stage_2_block_2
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_8[0][0]']
#  3_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_3
#  3_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_3
#  3_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_3
#  3_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_3
#  3_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_3
#  3_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_3
#  3_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_9 (TFOpLa  (None, 4, 4, 1024)  0           ['tf.__operators__.add_8[0][0]',
#  mbda)                                                            'convnext_xlarge_stage_2_block_3
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_9[0][0]']
#  4_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_4
#  4_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_4
#  4_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_4
#  4_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_4
#  4_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_4
#  4_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_4
#  4_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_10 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_9[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_4
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_10[0][0]']
#  5_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_5
#  5_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_5
#  5_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_5
#  5_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_5
#  5_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_5
#  5_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_5
#  5_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_11 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_10[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_5
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_11[0][0]']
#  6_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_6
#  6_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_6
#  6_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_6
#  6_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_6
#  6_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_6
#  6_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_6
#  6_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_12 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_11[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_6
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_12[0][0]']
#  7_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_7
#  7_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_7
#  7_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_7
#  7_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_7
#  7_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_7
#  7_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_7
#  7_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_13 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_12[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_7
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_13[0][0]']
#  8_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_8
#  8_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_8
#  8_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_8
#  8_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_8
#  8_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_8
#  8_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_8
#  8_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_14 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_13[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_8
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_14[0][0]']
#  9_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_9
#  9_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_9
#  9_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_9
#  9_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_9
#  9_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_9
#  9_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_9
#  9_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_15 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_14[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_9
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_15[0][0]']
#  10_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_1
#  10_layernorm (LayerNormalizati                                  0_depthwise_conv[0][0]']
#  on)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_1
#  10_pointwise_conv_1 (Dense)                                     0_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_1
#  10_gelu (Activation)                                            0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_1
#  10_pointwise_conv_2 (Dense)                                     0_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_1
#  10_layer_scale (LayerScale)                                     0_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_1
#  10_identity (Activation)                                        0_layer_scale[0][0]']
#
#  tf.__operators__.add_16 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_15[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_1
#                                                                  0_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_16[0][0]']
#  11_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_1
#  11_layernorm (LayerNormalizati                                  1_depthwise_conv[0][0]']
#  on)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_1
#  11_pointwise_conv_1 (Dense)                                     1_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_1
#  11_gelu (Activation)                                            1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_1
#  11_pointwise_conv_2 (Dense)                                     1_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_1
#  11_layer_scale (LayerScale)                                     1_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_1
#  11_identity (Activation)                                        1_layer_scale[0][0]']
#
#  tf.__operators__.add_17 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_16[0][0]',
# ...
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_2
#  24_layer_scale (LayerScale)                                     4_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_2
#  24_identity (Activation)                                        4_layer_scale[0][0]']
#
#  tf.__operators__.add_30 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_29[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_2
#                                                                  4_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_30[0][0]']
#  25_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_2
#  25_layernorm (LayerNormalizati                                  5_depthwise_conv[0][0]']
#  on)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_2
#  25_pointwise_conv_1 (Dense)                                     5_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_2
#  25_gelu (Activation)                                            5_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_2
#  25_pointwise_conv_2 (Dense)                                     5_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_2
#  25_layer_scale (LayerScale)                                     5_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_2
#  25_identity (Activation)                                        5_layer_scale[0][0]']
#
#  tf.__operators__.add_31 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_30[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_2
#                                                                  5_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  51200       ['tf.__operators__.add_31[0][0]']
#  26_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  2048        ['convnext_xlarge_stage_2_block_2
#  26_layernorm (LayerNormalizati                                  6_depthwise_conv[0][0]']
#  on)
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  4198400     ['convnext_xlarge_stage_2_block_2
#  26_pointwise_conv_1 (Dense)                                     6_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 4096)  0           ['convnext_xlarge_stage_2_block_2
#  26_gelu (Activation)                                            6_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  4195328     ['convnext_xlarge_stage_2_block_2
#  26_pointwise_conv_2 (Dense)                                     6_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  1024        ['convnext_xlarge_stage_2_block_2
#  26_layer_scale (LayerScale)                                     6_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 4, 4, 1024)  0           ['convnext_xlarge_stage_2_block_2
#  26_identity (Activation)                                        6_layer_scale[0][0]']
#
#  tf.__operators__.add_32 (TFOpL  (None, 4, 4, 1024)  0           ['tf.__operators__.add_31[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_2_block_2
#                                                                  6_identity[0][0]']
#
#  convnext_xlarge_downsampling_b  (None, None, None,   8392704    ['tf.__operators__.add_32[0][0]']
#  lock_2 (Sequential)            2048)
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  102400      ['convnext_xlarge_downsampling_bl
#  0_depthwise_conv (Conv2D)                                       ock_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  4096        ['convnext_xlarge_stage_3_block_0
#  0_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 8192)  16785408    ['convnext_xlarge_stage_3_block_0
#  0_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 8192)  0           ['convnext_xlarge_stage_3_block_0
#  0_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  16779264    ['convnext_xlarge_stage_3_block_0
#  0_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  2048        ['convnext_xlarge_stage_3_block_0
#  0_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  0           ['convnext_xlarge_stage_3_block_0
#  0_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_33 (TFOpL  (None, 2, 2, 2048)  0           ['convnext_xlarge_downsampling_bl
#  ambda)                                                          ock_2[0][0]',
#                                                                   'convnext_xlarge_stage_3_block_0
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  102400      ['tf.__operators__.add_33[0][0]']
#  1_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  4096        ['convnext_xlarge_stage_3_block_1
#  1_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 8192)  16785408    ['convnext_xlarge_stage_3_block_1
#  1_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 8192)  0           ['convnext_xlarge_stage_3_block_1
#  1_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  16779264    ['convnext_xlarge_stage_3_block_1
#  1_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  2048        ['convnext_xlarge_stage_3_block_1
#  1_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  0           ['convnext_xlarge_stage_3_block_1
#  1_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_34 (TFOpL  (None, 2, 2, 2048)  0           ['tf.__operators__.add_33[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_3_block_1
#                                                                  _identity[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  102400      ['tf.__operators__.add_34[0][0]']
#  2_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  4096        ['convnext_xlarge_stage_3_block_2
#  2_layernorm (LayerNormalizatio                                  _depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 8192)  16785408    ['convnext_xlarge_stage_3_block_2
#  2_pointwise_conv_1 (Dense)                                      _layernorm[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 8192)  0           ['convnext_xlarge_stage_3_block_2
#  2_gelu (Activation)                                             _pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  16779264    ['convnext_xlarge_stage_3_block_2
#  2_pointwise_conv_2 (Dense)                                      _gelu[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  2048        ['convnext_xlarge_stage_3_block_2
#  2_layer_scale (LayerScale)                                      _pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 2, 2, 2048)  0           ['convnext_xlarge_stage_3_block_2
#  2_identity (Activation)                                         _layer_scale[0][0]']
#
#  tf.__operators__.add_35 (TFOpL  (None, 2, 2, 2048)  0           ['tf.__operators__.add_34[0][0]',
#  ambda)                                                           'convnext_xlarge_stage_3_block_2
#                                                                  _identity[0][0]']
#
#  layer_normalization (LayerNorm  (None, 2, 2, 2048)  4096        ['tf.__operators__.add_35[0][0]']
#  alization)
#
#  flatten (Flatten)              (None, 8192)         0           ['layer_normalization[0][0]']
#
#  dense (Dense)                  (None, 4096)         33558528    ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 1072)         4391984     ['dense[0][0]']
#
#  dropout (Dropout)              (None, 1072)         0           ['dense_1[0][0]']
#
#  dense_2 (Dense)                (None, 7)            7511        ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 386,105,991
# Trainable params: 37,958,023
# Non-trainable params: 348,147,968
# __________________________________________________________________________________________________
