# %%
import itertools
import os

import matplotlib.pylab as plt
import numpy as np

import tensorflow as tf
import tensorflow_hub as hub
from keras.applications.vgg16 import VGG16
from keras.applications.vgg19 import VGG19
from keras.applications.resnet import ResNet50
import tensorflow_datasets as tfds

print("TF version:", tf.__version__)
print("Hub version:", hub.__version__)
print("GPU is", "available" if tf.test.is_gpu_available() else "NOT AVAILABLE")
# Out:
# WARNING:tensorflow:From <ipython-input-1-3f24911d649b>:16: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# TF version: 2.12.0
# Hub version: 0.13.0
# GPU is available

# %%
module_selection = ("inception_v3", 299) #@param ["(\"mobilenet_v2_100_224\", 224)", "(\"inception_v3\", 299)"] {type:"raw", allow-input: true}
handle_base, pixels = module_selection
MODULE_HANDLE ="https://tfhub.dev/google/imagenet/{}/feature_vector/4".format(handle_base)
IMAGE_SIZE = (pixels, pixels)
print("Using {} with input size {}".format(MODULE_HANDLE, IMAGE_SIZE))

BATCH_SIZE = 16 #@param {type:"integer"}
# Out:
# Using https://tfhub.dev/google/imagenet/inception_v3/feature_vector/4 with input size (299, 299)

# %%
(raw_train, raw_validation, raw_test), metadata = tfds.load(
    name="oxford_flowers102",
    split=['test', 'validation', 'train'],
    with_info=True,
    as_supervised=True,
    batch_size=32
)

# %%
IMAG_SIZE = 224 # All images will be resized to 224x224
def normalize_img(image, label):
  """Normalizes images: `uint8` -> `float32`."""
  image = tf.cast(image, tf.float32)
  image = (image/127.5) - 1
  image = tf.image.resize(image, (IMAG_SIZE, IMAG_SIZE))
  return  image, label

# %%
train = raw_train.map(normalize_img)
validation = raw_validation.map(normalize_img)
test = raw_test.map(normalize_img)

# %%
# print("Building model with", MODULE_HANDLE)
# conv_base = ResNet50(include_top=False, weights='imagenet', input_shape=(IMAG_SIZE, IMAG_SIZE,3))

inception = tf.keras.applications.InceptionResNetV2(include_top=False,input_shape=(IMAG_SIZE,IMAG_SIZE,3),pooling='avg',classes=102,weights='imagenet')

for layer in resnet.layers:
    layer.trainable = False

model = tf.keras.Sequential([
    inception,
    tf.keras.layers.Flatten(name="flatten"),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dense(1072, activation='relu'),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(units=metadata.features["label"].num_classes)
])

model.build((None,)+IMAGE_SIZE+(3,))
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 11s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 1536)             54336736
#  onal)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 4096)              6295552
#
#  dense_1 (Dense)             (None, 1072)              4391984
#
#  dropout (Dropout)           (None, 1072)              0
#
#  dense_2 (Dense)             (None, 102)               109446
#
# =================================================================
# Total params: 65,133,718
# Trainable params: 10,796,982
# Non-trainable params: 54,336,736
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
checkpoint_filepath = "/tmp/checkpoint"
checkpoint_callback = ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True,
)

earlystopping = EarlyStopping(monitor='val_loss', patience=5)

model.compile(
  optimizer=tf.keras.optimizers.Adam(learning_rate=.5e-3), 
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
train = train.unbatch().batch(BATCH_SIZE,drop_remainder=True).repeat().shuffle(512)
validation = validation.unbatch().batch(BATCH_SIZE,drop_remainder=True).repeat()

# %%
steps_per_epoch = metadata.splits["train"].num_examples / BATCH_SIZE 
validation_steps = metadata.splits["validation"].num_examples / BATCH_SIZE
EPOCHS = 40
hist = model.fit(
    x=train,
    epochs=EPOCHS, steps_per_epoch=steps_per_epoch,
    validation_data=validation,
    validation_steps=validation_steps,
    callbacks=[checkpoint_callback],
    verbose=1).history
# Out:
# Epoch 1/40
# 63/63 [==============================] - 72s 342ms/step - loss: 4.0789 - accuracy: 0.1592 - val_loss: 3.9661 - val_accuracy: 0.1504
# Epoch 2/40
# 63/63 [==============================] - 15s 238ms/step - loss: 2.9945 - accuracy: 0.3086 - val_loss: 3.3745 - val_accuracy: 0.2070
# Epoch 3/40
# 63/63 [==============================] - 15s 229ms/step - loss: 2.5585 - accuracy: 0.3721 - val_loss: 2.8768 - val_accuracy: 0.2656
# Epoch 4/40
# 63/63 [==============================] - 17s 261ms/step - loss: 2.2512 - accuracy: 0.4326 - val_loss: 2.5066 - val_accuracy: 0.3389
# Epoch 5/40
# 63/63 [==============================] - 20s 316ms/step - loss: 2.0911 - accuracy: 0.4404 - val_loss: 2.4285 - val_accuracy: 0.3838
# Epoch 24/40
# 63/63 [==============================] - 17s 264ms/step - loss: 0.7149 - accuracy: 0.7725 - val_loss: 1.2077 - val_accuracy: 0.6650
# Epoch 25/40
# 63/63 [==============================] - 17s 262ms/step - loss: 0.7095 - accuracy: 0.7891 - val_loss: 1.1829 - val_accuracy: 0.6523
# Epoch 26/40
# 63/63 [==============================] - 17s 264ms/step - loss: 0.6263 - accuracy: 0.8135 - val_loss: 1.1367 - val_accuracy: 0.6816
# Epoch 27/40
# 63/63 [==============================] - 13s 204ms/step - loss: 0.5949 - accuracy: 0.8213 - val_loss: 1.1489 - val_accuracy: 0.6797
# Epoch 28/40
# 63/63 [==============================] - 17s 263ms/step - loss: 0.6847 - accuracy: 0.7803 - val_loss: 1.0824 - val_accuracy: 0.6719
# Epoch 29/40
# 63/63 [==============================] - 24s 378ms/step - loss: 0.5904 - accuracy: 0.8184 - val_loss: 1.0747 - val_accuracy: 0.6914
# Epoch 30/40
# 63/63 [==============================] - 17s 261ms/step - loss: 0.5694 - accuracy: 0.8271 - val_loss: 1.1321 - val_accuracy: 0.6875
# Epoch 31/40
# 63/63 [==============================] - 18s 291ms/step - loss: 0.5073 - accuracy: 0.8457 - val_loss: 1.1066 - val_accuracy: 0.7021
# Epoch 32/40
# 63/63 [==============================] - 13s 206ms/step - loss: 0.5785 - accuracy: 0.8164 - val_loss: 1.2500 - val_accuracy: 0.6719
# Epoch 33/40
# 63/63 [==============================] - 13s 204ms/step - loss: 0.6495 - accuracy: 0.8027 - val_loss: 1.1593 - val_accuracy: 0.6855
# Epoch 34/40
# 63/63 [==============================] - 18s 286ms/step - loss: 0.5547 - accuracy: 0.8311 - val_loss: 1.0601 - val_accuracy: 0.7080
# Epoch 35/40
# 63/63 [==============================] - 13s 204ms/step - loss: 0.5641 - accuracy: 0.8184 - val_loss: 1.0235 - val_accuracy: 0.7070
# Epoch 36/40
# 63/63 [==============================] - 14s 229ms/step - loss: 0.4773 - accuracy: 0.8584 - val_loss: 1.0386 - val_accuracy: 0.7207
# Epoch 37/40
# 63/63 [==============================] - 13s 206ms/step - loss: 0.4756 - accuracy: 0.8594 - val_loss: 1.0558 - val_accuracy: 0.7207
# Epoch 38/40
# 63/63 [==============================] - 15s 234ms/step - loss: 0.4410 - accuracy: 0.8672 - val_loss: 1.0126 - val_accuracy: 0.7246
# Epoch 39/40
# 63/63 [==============================] - 15s 238ms/step - loss: 0.4304 - accuracy: 0.8682 - val_loss: 0.9256 - val_accuracy: 0.7422
# Epoch 40/40
# 63/63 [==============================] - 13s 212ms/step - loss: 0.4015 - accuracy: 0.8760 - val_loss: 1.0812 - val_accuracy: 0.7080

# %%
plt.plot(hist["loss"], label="train_loss")
plt.plot(hist["val_loss"], label="val_loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Train and Validation Losses Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

plt.plot(hist["accuracy"], label="test_accuracy")
plt.plot(hist["val_accuracy"], label="val_accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.title("Train and Validation accuracies Over Epochs", fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
image_batch = []
label_batch = []
image_batch, label_batch = next(iter(test))

t = list(test.as_numpy_iterator())

for i in range(len(test)-1):
    image_batch = np.append(image_batch, t[i+1][0], axis=0)
    label_batch = np.append(label_batch, t[i+1][1], axis=0)


image_batch = image_batch
label_batch = label_batch

predicted_batch = model.predict(image_batch)
predicted_batch = tf.squeeze(predicted_batch).numpy()

predicted_ids = np.argmax(predicted_batch, axis=-1)
# predicted_class_names = class_names[predicted_ids]
# print(predicted_class_names)
# Out:
# 32/32 [==============================] - 12s 210ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Converter as previsões em rótulos de classe
predicted_classes = predicted_ids#np.argmax(probs, axis=1)

# Obter os rótulos verdadeiros do conjunto de dados de validação
true_classes = label_batch#np.argmax(y_test, axis=1)

# Obter os nomes das classes
# class_names = list(validgen.class_indices.keys())

# Calcular a precisão
accuracy = np.mean(predicted_classes == true_classes)
print('Precisão:', accuracy)
# Out:
# Precisão: 0.6931372549019608

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report

# Calcular a precisão, recall e F1-score para cada classe
report = classification_report(true_classes, predicted_classes, target_names=np.array(metadata.features['label'].names))

# Exibir o relatório de classificação
print(report)
# Out:
#                            precision    recall  f1-score   support
#
#             pink primrose       1.00      0.30      0.46        10
# hard-leaved pocket orchid       1.00      1.00      1.00        10
#          canterbury bells       0.00      0.00      0.00        10
#                 sweet pea       0.50      0.10      0.17        10
#          english marigold       1.00      0.50      0.67        10
#                tiger lily       0.78      0.70      0.74        10
#               moon orchid       1.00      0.50      0.67        10
#          bird of paradise       0.91      1.00      0.95        10
#                 monkshood       0.45      0.50      0.48        10
#             globe thistle       1.00      0.50      0.67        10
#                snapdragon       0.29      0.60      0.39        10
#               colt's foot       0.62      0.80      0.70        10
#               king protea       0.67      0.60      0.63        10
#             spear thistle       1.00      0.80      0.89        10
#               yellow iris       0.88      0.70      0.78        10
#              globe-flower       1.00      0.30      0.46        10
#         purple coneflower       0.53      1.00      0.69        10
#             peruvian lily       0.55      0.60      0.57        10
#            balloon flower       0.78      0.70      0.74        10
#     giant white arum lily       0.78      0.70      0.74        10
#                 fire lily       1.00      0.70      0.82        10
#         pincushion flower       0.75      0.30      0.43        10
#                fritillary       1.00      0.90      0.95        10
#                red ginger       0.78      0.70      0.74        10
#            grape hyacinth       1.00      0.70      0.82        10
#                corn poppy       1.00      0.60      0.75        10
#  prince of wales feathers       1.00      0.90      0.95        10
#          stemless gentian       0.36      0.80      0.50        10
#                 artichoke       0.82      0.90      0.86        10
#             sweet william       0.82      0.90      0.86        10
#                 carnation       0.23      0.50      0.31        10
#              garden phlox       0.00      0.00      0.00        10
#          love in the mist       1.00      0.80      0.89        10
#             mexican aster       0.86      0.60      0.71        10
#          alpine sea holly       0.47      0.90      0.62        10
#      ruby-lipped cattleya       0.50      0.20      0.29        10
#               cape flower       0.82      0.90      0.86        10
#          great masterwort       0.80      0.80      0.80        10
#                siam tulip       0.67      0.40      0.50        10
#               lenten rose       0.45      0.50      0.48        10
#            barbeton daisy       0.43      1.00      0.61        10
#                  daffodil       1.00      0.30      0.46        10
#                sword lily       0.18      0.80      0.29        10
#                poinsettia       0.90      0.90      0.90        10
#          bolero deep blue       1.00      0.40      0.57        10
#                wallflower       0.75      0.90      0.82        10
#                  marigold       1.00      1.00      1.00        10
#                 buttercup       0.78      0.70      0.74        10
#               oxeye daisy       1.00      0.90      0.95        10
#          common dandelion       0.83      0.50      0.62        10
#                   petunia       0.45      0.90      0.60        10
#                wild pansy       0.80      0.80      0.80        10
#                   primula       0.62      0.80      0.70        10
#                 sunflower       1.00      0.20      0.33        10
#               pelargonium       0.64      0.70      0.67        10
#        bishop of llandaff       0.88      0.70      0.78        10
#                     gaura       0.80      0.80      0.80        10
#                  geranium       0.91      1.00      0.95        10
#             orange dahlia       0.71      1.00      0.83        10
#       pink-yellow dahlia?       0.83      1.00      0.91        10
#          cautleya spicata       0.70      0.70      0.70        10
#          japanese anemone       0.75      0.60      0.67        10
#          black-eyed susan       0.89      0.80      0.84        10
#                silverbush       1.00      0.80      0.89        10
#         californian poppy       1.00      0.80      0.89        10
#              osteospermum       1.00      1.00      1.00        10
#             spring crocus       1.00      0.30      0.46        10
#              bearded iris       0.80      0.40      0.53        10
#                windflower       1.00      1.00      1.00        10
#                tree poppy       0.75      0.90      0.82        10
#                   gazania       0.83      1.00      0.91        10
#                    azalea       0.57      0.40      0.47        10
#                water lily       0.80      0.80      0.80        10
#                      rose       0.64      0.90      0.75        10
#               thorn apple       0.83      1.00      0.91        10
#             morning glory       0.80      0.80      0.80        10
#            passion flower       0.83      1.00      0.91        10
#                     lotus       0.90      0.90      0.90        10
#                 toad lily       1.00      0.60      0.75        10
#                 anthurium       1.00      0.90      0.95        10
#                frangipani       0.73      0.80      0.76        10
#                  clematis       0.60      0.60      0.60        10
#                  hibiscus       0.62      0.50      0.56        10
#                 columbine       0.75      0.30      0.43        10
#               desert-rose       0.62      0.80      0.70        10
#               tree mallow       0.71      1.00      0.83        10
#                  magnolia       1.00      1.00      1.00        10
#                  cyclamen       0.35      0.70      0.47        10
#                watercress       0.53      1.00      0.69        10
#                canna lily       0.25      0.30      0.27        10
#               hippeastrum       0.80      0.40      0.53        10
#                  bee balm       0.80      0.40      0.53        10
#                 ball moss       1.00      0.60      0.75        10
#                  foxglove       0.90      0.90      0.90        10
#             bougainvillea       0.78      0.70      0.74        10
#                  camellia       0.73      0.80      0.76        10
#                    mallow       0.71      0.50      0.59        10
#           mexican petunia       0.50      0.90      0.64        10
#                  bromelia       0.53      1.00      0.69        10
#            blanket flower       1.00      0.20      0.33        10
#           trumpet creeper       0.83      0.50      0.62        10
#           blackberry lily       1.00      1.00      1.00        10
#
#                  accuracy                           0.69      1020
#                 macro avg       0.76      0.69      0.69      1020
#              weighted avg       0.76      0.69      0.69      1020
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
